# %%
# Initialize Otter
import otter
grader = otter.Notebook("proj4.ipynb")

# %% [markdown]
# # Project 4: Mongo
#
# ## Due Date: Friday 11/18, 11:59 PM
# ### Checkpoint: Thursday 11/10, 11:59 PM
#
# In this project, we will be investigating how different database systems handle semi-structured JSON data. In particular, we will be placing emphasis on the use of MongoDB: a database system that stores data in a construct known as documents. These documents are very similar to the JSON objects we've explored in lecture with a few differences in representation and indexing that we will explore in the following questions. In this project, we will be working with the Yelp Academic Dataset which contains a dataset of `businesses`, `reviews`, and `users`. Due to the limitations of JupyterHub and the Mongo instances we are working with, `reviews` and `users` are truncated to 7500 reviews and 1000 users. We will be using the full `businesses` dataset, however.
#
# Throughout the course of this project, you should understand what Mongo can (and cannot) do with regards to its documents as a NoSQL datastore and compare and contrast this to other data representation formats such as the relational model.

# %% [markdown]
# ## Logistics & Scoring Breakdown
#
# For Data 101 students, this project is worth 15% of your grade. For Info 258 students, this project is worth 12% of your grade.
#
# If you make a non-trivial submission to the **Project 4 \[CHECKPOINT\]** assignment on Gradescope before **Thursday 11/10 11:59PM**, you will earn an extra credit point on this project. We will define "non-trivial" as scoring at least 5 points on the coding portion of the assignment. If you pass all the public tests in Question 1, you are guaranteed to receive the extra credit point. No late submissions will be allowed for the checkpoint.
#
# For the final submission that will be graded, please submit to **Project 4 \[FINAL\]** assignment on Gradescope. Please read the submission instructions carefully and double check that your submission is not throwing any errors.
#
# Each coding question has **both public tests and hidden tests**. Roughly 50% of your coding grade will be made up of your score on the public tests released to you, while the remaining 50% will be made up of unreleased hidden tests. Free-response questions will be manually graded.
#
# This is an **individual project**. However, you’re welcome to collaborate with any other student in the class as long as it’s within the academic honesty guidelines.
#
# Question | Points
# --- | ---
# 1a	| 1
# 1b  | 1
# 1c	| 2
# 1d	| 1
# 1e	| 2
# 1f  | 1
# 2a	| 2
# 2b	| 1
# 2c  | 1
# 2d  | 2
# 3a	| 1
# 3b	| 1
# 3c	| 1
# 3d  | 1
# 3e  | 1
# 3f  | 3
# 4a	| 1
# 4b	| 2
# 4c	| 2
# 4d  | 1
# **Total** | 28

# %% [markdown]
# ## Loading Up Mongo
# We will be using Pymongo, a Python wrapper for MongoDB, for this project. Every student should have access to their own MongoDB instance, running on the localhost of your Datahub server. After running the following cell, for the rest of the project, you can use the Python variables business, review, and user to access the corresponding collection.

# %%
import pickle
import pandas as pd
import pymongo
from pymongo import TEXT

myclient = pymongo.MongoClient("mongodb://localhost")
mydb = myclient["yelp"]
business = mydb["business"]
review = mydb["review"]
user = mydb["user"]

# %%
myclient,mydb,business,review,user
# Out:
# (MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True),
#  Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'yelp'),
#  Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'yelp'), 'business'),
#  Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'yelp'), 'review'),
#  Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'yelp'), 'user'))

# %% [markdown]
# ## Troubleshooting
#
# **PLEASE READ:** Please avoid printing too much debugging query output - it may crash your Jupyter Hub if your file size becomes too large! It's recommended to delete any debugging query cells if no longer needed as you go through the project.
#
# You might run into issues on the project where you are certain your code works but the output is incorrect. This may be because your collections have been corrupted. Run the following cell and uncomment the specific collections you would like to drop if you would like to remake your collections from scratch. **Be sure to re-run the Load Datasets cells below if you drop your collections so you aren't working with empty collections!**

# %%
# UNCOMMENT AND RUN THIS CELL IF YOU WOULD LIKE TO REMAKE YOUR COLLECTIONS FROM SCRATCH. 
# IF YOU DROP ANY COLLECTIONS, RE-RUN THE NEXT TWO CELLS TO LOAD IN THE DATA.

#review.drop()
# business.drop()
# user.drop()

# %% [markdown]
# ## Load Datasets
# The following 2 cells will load the JSON datasets into the appropriate Mongo collections. You will only need to run them once unless you drop the collections above. The second cell **may take a couple of minutes to run** if you are running it for the first time or are running it after you dropped the collections.

# %%
import zipfile
import os.path

if not os.path.isfile('data/yelp_academic_dataset_review.json'):
    with zipfile.ZipFile('data/yelp_academic_dataset_review.json.zip', 'r') as zip_ref:
        zip_ref.extractall('data')

if not os.path.isfile('data/yelp_academic_dataset_user.json'):
    with zipfile.ZipFile('data/yelp_academic_dataset_user.json.zip', 'r') as zip_ref:
        zip_ref.extractall('data')

if not os.path.isfile('data/yelp_academic_dataset_business.json'):
    with zipfile.ZipFile('data/yelp_academic_dataset_business.json.zip', 'r') as zip_ref:
        zip_ref.extractall('data')

# %%
# THIS CELL MAY TAKE AT MOST 5 MINUTES. BUT HOPEFULLY YOU WILL ONLY NEED TO RUN IT ONCE.
import json

if business.count_documents({}) == 0:
    print("Loading business collection...")
    with open('data/yelp_academic_dataset_business.json', encoding='utf-8') as f:
        for line in f:
            business.insert_one(json.loads(line))

if review.count_documents({}) == 0:
    print("Loading review collection...")
    with open('data/yelp_academic_dataset_review.json', encoding='utf-8') as f:
        for line in f:
            review.insert_one(json.loads(line))
            
if user.count_documents({}) == 0:
    print("Loading user collection...")
    with open('data/yelp_academic_dataset_user.json', encoding='utf-8') as f:
        for line in f:
            user.insert_one(json.loads(line))

# %% [markdown]
# Let's take a quick look at our collections. For the command below, replace `user` with `review` or `business` to count the number of documents in each collection.

# %%
user.count_documents({})
# Out:
# 1000

# %%
review.count_documents({})
# Out:
# 7500

# %%
business.count_documents({})
# Out:
# 160585

# %% [markdown]
# Now let's inspect our collections. Replace `business` with `review` and `user` to see the first document in each collection.

# %%
business.find_one()
# Out:
# {'_id': ObjectId('6365c56f01bec29b734e4e9c'),
#  'business_id': '6iYb2HFDywm3zjuRg0shjw',
#  'name': 'Oskar Blues Taproom',
#  'address': '921 Pearl St',
#  'city': 'Boulder',
#  'state': 'CO',
#  'postal_code': '80302',
#  'latitude': 40.0175444,
#  'longitude': -105.2833481,
#  'stars': 4.0,
#  'review_count': 86,
#  'is_open': 1,
#  'attributes': {'RestaurantsTableService': 'True',
#   'WiFi': "u'free'",
#   'BikeParking': 'True',
#   'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#   'BusinessAcceptsCreditCards': 'True',
#   'RestaurantsReservations': 'False',
#   'WheelchairAccessible': 'True',
#   'Caters': 'True',
#   'OutdoorSeating': 'True',
#   'RestaurantsGoodForGroups': 'True',
#   'HappyHour': 'True',
#   'BusinessAcceptsBitcoin': 'False',
#   'RestaurantsPriceRange2': '2',
#   'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': True}",
#   'HasTV': 'True',
#   'Alcohol': "'beer_and_wine'",
#   'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}",
#   'DogsAllowed': 'False',
#   'RestaurantsTakeOut': 'True',
#   'NoiseLevel': "u'average'",
#   'RestaurantsAttire': "'casual'",
#   'RestaurantsDelivery': 'None'},
#  'categories': 'Gastropubs, Food, Beer Gardens, Restaurants, Bars, American (Traditional), Beer Bar, Nightlife, Breweries',
#  'hours': {'Monday': '11:0-23:0',
#   'Tuesday': '11:0-23:0',
#   'Wednesday': '11:0-23:0',
#   'Thursday': '11:0-23:0',
#   'Friday': '11:0-23:0',
#   'Saturday': '11:0-23:0',
#   'Sunday': '11:0-23:0'}}

# %% [markdown]
# If you see a document containing a business named `Oskar Blues Taproom` when you run the command above, it means that our JSON data has successfully been imported into the collection! Now we can get started with exploring Mongo in a bit more detail.
#
# **Todo:** Run the two cells below for grading purposes.

# %%
# Do not delete/edit this cell
# !mkdir -p results

# %%
# Do not delete/edit this cell
import pickle
import pandas as pd

# %% [markdown]
# ## Question 1: Basic MQL
#
# ### Question 1a
#
# In lecture, we discussed how one could find specific attributes from a JSON object using dot notation.
#
# While you can still use the dot notation in queries, PyMongo represents documents returned from Mongo queries using Python dictionaries, making it convenient to manipulate JSON using a mix of Mongo queries and array indexing. Specifically, given the result of a retrieval `find` query, you can look up the third document by appending `[2]`. Then, given this document, you can look up the field `'amount'` by appending `['amount']` etc., adding multiple square brackets as needed to "walk down" the JSON tree representation via `collection.find(...)[2]['amount']`.
#
# In order to get a visual output of the query results, you will need to wrap `collection.find(...)` inside `list()`, e.g. `list(collection.find(...))`. This is because `collection.find(...)` returns a **Cursor** object, which is an iterator. **An important consequence** is that if we set `result = collection.find(...)`, then calling `list(result)` for the first time will get you the expected list of documents in the query result, but calling `list(result)` for a second time will give you an empty list! So wrapping `collection.find(...)` directly inside `list()` would avoid this issue.
#
# Another note - since we are using Python dictionaries as our query filter, make sure to wrap all keys and values inside quotes.
#
# As a warmup to get you familiarized with PyMongo syntax, find the Tuesday hours for the restaurant named **Legal Sea Foods** at **100 Huntington Ave** in **Boston**. Be careful - there are many Legal Sea Foods in Boston!

# %%
result_1a = list(business.find({'name':'Legal Sea Foods','address': '100 Huntington Ave','city': 'Boston'}))[0]['hours']['Tuesday']

# %%
# Do not delete/edit this cell
pickle.dump(result_1a, open("results/result_1a.p", "wb"))

# %%
grader.check("q1a")
# Out:
# q1a results: All test cases passed!

# %% [markdown]
# ### Question 1b
# Now let's get some practice with aggregation and filtering. Our goal is to write a query that computes the average star rating for all businesses in Colorado with 30 reviews or greater. However, this won't be as easy as setting the state to CO! If we inspect this dataset more closely, we will notice that some cities are not matched up with the right states. As an example, run the query below.

# %%
list(business.find({"state": "CA"}).limit(3))
# Out:
# [{'_id': ObjectId('6365c57001bec29b734e55b7'),
#   'business_id': 'SNCRnaSy6E5fHgQuoCmmbQ',
#   'name': 'Katia Photography',
#   'address': '',
#   'city': 'Portland',
#   'state': 'CA',
#   'postal_code': '97007',
#   'latitude': 45.4501529,
#   'longitude': -122.8849111,
#   'stars': 5.0,
#   'review_count': 11,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsBitcoin': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'WiFi': "u'no'"},
#   'categories': 'Shopping, Clothing Rental, Event Planning & Services, Fashion, Event Photography, Photographers, Session Photography',
#   'hours': {'Monday': '8:0-22:0',
#    'Tuesday': '8:0-22:0',
#    'Wednesday': '8:0-22:0',
#    'Thursday': '8:0-22:0',
#    'Friday': '8:0-22:0',
#    'Saturday': '8:0-22:0',
#    'Sunday': '8:0-22:0'}},
#  {'_id': ObjectId('6365c58301bec29b734ec623'),
#   'business_id': 'cjwnQMQOGOYgB5uNmiYWLA',
#   'name': 'Verizon Authorized Retailer - GoWireless',
#   'address': '4655 SW Griffith Dr, Ste 125',
#   'city': 'Beaverton',
#   'state': 'CA',
#   'postal_code': '97005',
#   'latitude': 45.486312,
#   'longitude': -122.796487,
#   'stars': 2.5,
#   'review_count': 9,
#   'is_open': 0,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'BusinessParking': 'None',
#    'ByAppointmentOnly': 'False',
#    'BikeParking': 'True'},
#   'categories': 'Mobile Phones, Telecommunications, Shopping, Home Services, IT Services & Computer Repair, Internet Service Providers, Local Services, Professional Services, Mobile Phone Accessories, Electronics',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '10:0-18:0',
#    'Wednesday': '10:0-18:0',
#    'Thursday': '10:0-18:0',
#    'Friday': '10:0-18:0',
#    'Saturday': '10:0-18:0',
#    'Sunday': '11:0-18:0'}},
#  {'_id': ObjectId('6365c58d01bec29b734f090a'),
#   'business_id': 'l92RJMHpxZgJl7FQuqpW6w',
#   'name': 'Here We Grow',
#   'address': '',
#   'city': 'Atlanta',
#   'state': 'CA',
#   'postal_code': '30345',
#   'latitude': 33.8484195,
#   'longitude': -84.2858121,
#   'stars': 5.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'GoodForKids': 'True'},
#   'categories': 'Childbirth Education, Specialty Schools, Preschools, Adult Education, Parenting Classes, Education, Active Life, Kids Activities',
#   'hours': {'Tuesday': '9:0-17:0',
#    'Thursday': '9:0-17:0',
#    'Saturday': '9:0-13:0',
#    'Sunday': '11:0-15:0'}}]

# %% [markdown]
# Notice how cities like Portland and Atlanta, and Orlando are classified as California cities! However, the latitude and longitude is generally correct. The latitude of Colorado is between 37 and 41 **inclusive** and the longitude is between -109 and -102 **inclusive**. Now, use this to **find the average star rating** of all businesses in this range with **30 or more reviews**.
#
# Recall that in SQL, we would use a GROUP BY with the AVG aggregation function. In Mongo, we use an aggregation pipeline, comprised of multiple stages. Each stage transforms the documents in some way. Pipeline stages do not need to produce one output document for every input document. For example, some stages may generate new documents or filter out documents.
#
# **Hint 1**: as in the previous question, you may find it helpful to use the PyMongo array notation to extract the pertinent information once you have composed the right Mongo aggregation query. You are required to wrap `collection.aggregate(...)` inside `list()`, e.g. `list(collection.aggregate(...))` before indexing / visualizing the output. Similar to `collection.find(...)`, `collection.aggregate(...)` also returns a **Cursor** object (which is an iterator).
#
# **Hint 2**: you can set multiple conditions for a given field within the same object, e.g. `{"$gte": 0, "$lte": 10}`. This is the recommended approach, or else you may need to worry about the ordering between the conditions.

# %%
list(business.aggregate([
    {'$match' : {"latitude":{"$gte": 37,"$lte":41} ,'longitude':{"$gte": -109,"$lte":-102}, 
                 'review_count': {'$gte': 30}}},
    {'$group' : {'_id': 'null', 'avgStar': {'$avg' : '$stars'}}}
    
]))
# Out:
# [{'_id': 'null', 'avgStar': 3.6735412474849096}]

# %%
result_1b = list(business.aggregate([
    {'$match' : {"latitude":{"$gte": 37,"$lte":41} ,'longitude':{"$gte": -109,"$lte":-102}, 
                 'review_count': {'$gte': 30}}},
    {'$group' : {'_id': 'null', 'avgStar': {'$avg' : '$stars'}}}
    
]))[0]['avgStar']

# %%
# Do not delete/edit this cell
pickle.dump(result_1b, open("results/result_1b.p", "wb"))

# %%
grader.check("q1b")
# Out:
# q1b results: All test cases passed!

# %% [markdown]
# ### Question 1c
#
# In this question, we will explore aggregation and grouping further. We will also make use of the `$project` operator which allows us to output documents with certain fields of our choosing.
#
# For this question, we would like to create an aggregation pipeline to find the town in each state with the highest average number of stars. **We will only consider towns with greater than or equal to 5 reviews in total across all the restaurants in that town so that the average is meaningful.** Your final output should contain exactly two fields: `city_state` which is the name of the town with the highest value of average stars in the state concatenated with a comma followed by the state initials and `averageStars` which contains the average number of stars for the corresponding town. To ensure your output is consistent with the autograder, sort in descending order by `averageStars` and break ties by sorting second on `city_state` in alphabetical (ascending) order.
#
# As a concrete example, imagine that Berkeley and Austin have the highest average stars in California and Texas respectively (and both have more than or equal to 5 total reviews). If Berkeley and Austin both have an average star rating of 5.0, your final output should be:
#
# ```
# {'averageStars': 5.0, 'city_state': 'Austin, TX'}
# {'averageStars': 5.0, 'city_state': 'Berkeley, CA'}
# ```
#
# **Note:** You will provide a pipeline to `business.aggregate(...)` as your solution. Save your pipeline to `q1c_pipeline`.
#
# **Hint:** You may find the `concat` operator helpful. See: https://docs.mongodb.com/manual/reference/operator/aggregation/concat/

# %%
{'_id': {'state': 'ABE', 'city': 'Vancouver'}, 'avgStar': 4.5},
{'_id': {'state': 'AL', 'city': 'Austin'}, 'avgStar': 2.5},
{'_id': {'state': 'AZ', 'city': 'Salem'}, 'avgStar': 4.5},
{'_id': {'state': 'BC', 'city': 'West Point Grey'},'avgStar': 5.0},
# Out:
# ({'_id': {'state': 'BC', 'city': 'West Point Grey'}, 'avgStar': 5.0},)

# %%
list(business.aggregate([  
    {'$group' : {'_id' : {'state': '$state','city': '$city'},
                 'totalReview' : {'$sum' : '$review_count'},
                 'avgStar': {'$avg': '$stars'}}},
    {'$match' : {'totalReview' : {'$gte' : 5}}},
    {'$sort' : {'_id.city': 1, 'avgStar': -1}},
    {'$group' :{'_id' : {'state': '$_id.state'},
                'city' :  {"$first" : '$_id.city'}, 
                'averageStars' : {"$first" : '$avgStar'}}},
    {'$project' : {'_id':0,'averageStars':1,
                   'city_state' : {'$concat' : ['$city', ', ','$_id.state']}}},
    {'$sort' : {'averageStars':-1, 'city_state': 1}}   
    
    
    
    
  
    
    
  

    
    ]))
# Out:
# [{'averageStars': 5.0, 'city_state': 'Atlanta, CA'},
#  {'averageStars': 5.0, 'city_state': 'Kings County, NY'},
#  {'averageStars': 5.0, 'city_state': 'Vancouver, DC'},
#  {'averageStars': 4.75, 'city_state': 'AUBURNDALE, MA'},
#  {'averageStars': 4.5, 'city_state': 'Alton, OH'},
#  {'averageStars': 4.5, 'city_state': 'Portland, HI'},
#  {'averageStars': 4.5, 'city_state': 'Powell, DE'},
#  {'averageStars': 4.5, 'city_state': 'Vancouver, ABE'},
#  {'averageStars': 4.25, 'city_state': 'Anmore, BC'},
#  {'averageStars': 4.0, 'city_state': 'Franklin Park, IL'},
#  {'averageStars': 3.75, 'city_state': 'Beaverton, WA'},
#  {'averageStars': 3.7333333333333334, 'city_state': 'AUSTIN, TX'},
#  {'averageStars': 3.651315789473684, 'city_state': 'Aloha, OR'},
#  {'averageStars': 3.5, 'city_state': 'Austin, MN'},
#  {'averageStars': 3.5, 'city_state': 'Glendale, WI'},
#  {'averageStars': 3.5, 'city_state': 'Jackson, MI'},
#  {'averageStars': 3.5, 'city_state': 'Lake Oswego, AZ'},
#  {'averageStars': 3.5, 'city_state': 'Norfolk, VA'},
#  {'averageStars': 3.5, 'city_state': 'North Reading, ME'},
#  {'averageStars': 3.5, 'city_state': 'Rio Rancho, NM'},
#  {'averageStars': 3.272727272727273, 'city_state': 'ATLANTA, GA'},
#  {'averageStars': 3.0, 'city_state': 'Arvada, CO'},
#  {'averageStars': 3.0, 'city_state': 'Danville, NH'},
#  {'averageStars': 2.5, 'city_state': 'Austin, AL'},
#  {'averageStars': 2.5, 'city_state': 'Burnaby, ON'},
#  {'averageStars': 2.5, 'city_state': 'Oklahoma City, OK'},
#  {'averageStars': 2.5, 'city_state': 'Sanford, NC'},
#  {'averageStars': 2.0, 'city_state': '51 Richard Beall Hwy 17-92, FL'},
#  {'averageStars': 2.0, 'city_state': 'Ellsworth, KS'},
#  {'averageStars': 2.0, 'city_state': 'Liberty, KY'},
#  {'averageStars': 1.5, 'city_state': 'Sheridan, WY'}]

# %%
q1c_pipeline = [  
    {'$group' : {'_id' : {'state': '$state','city': '$city'},
                 'totalReview' : {'$sum' : '$review_count'},
                 'avgStar': {'$avg': '$stars'}}},
    {'$match' : {'totalReview' : {'$gte' : 5}}},
    {'$sort' : {'_id.city': 1, 'avgStar': -1}},
    {'$group' :{'_id' : {'state': '$_id.state'},
                'city' :  {"$first" : '$_id.city'}, 
                'averageStars' : {"$first" : '$avgStar'}}},
    {'$project' : {'_id':0,'averageStars':1,
                   'city_state' : {'$concat' : ['$city', ', ','$_id.state']}}},
    {'$sort' : {'averageStars':-1, 'city_state': 1}}   
    
    
    
    
  

    
    ]
    

result_1c = list(business.aggregate(q1c_pipeline))

# %%
# Do not delete/edit this cell
result_1c = list(business.aggregate(q1c_pipeline))
pickle.dump(result_1c, open("results/result_1c.p", "wb"))

# %%
grader.check("q1c")
# Out:
# q1c results: All test cases passed!

# %% [markdown]
# ### Question 1d
#
# In class, we've described structured (rectangular) data as well as semi-structured data. We haven't quite covered unstructured data -- this is basically free-form text. Often, in semi-structured JSON you may have unstructured text data embedded within, such as the text field in the review collection.
#
# MongoDB allows us to build a so-called **text index** to retrieve the relevant document based on keywords found in text in a predefined field. This index converts our free-form text into a structure that allows us to easily look up documents by its contents. To leverage this text search capability, we build a text index on the `text` field in the `review` collection. This has been done for you.
#
# We will then use this text index to do basic sentiment analysis and find all the restaurants we should avoid! Using the text index given, write a query to find all the reviews with "disgusting", "horrible", "horrid", "gross", "bad", or "hate". To use the text index, use the keywords `$text` and `$search` as detailed here: https://www.mongodb.com/docs/manual/core/text-search-operators/.
#
# Fill in your query into `result_1d` to count how many reviews contain any of these 6 words.
#
# **Hint:** In general, you can count the number of documents returned by a `find` query result via `len(list(collection.find(...)))` or more simply `collection.count_documents(...)`. To count the number of documents returned by an `aggregate` query result, the best way is to directly use `len(list(collection.aggregate(...)))`.

# %%
if 'text_text' not in review.index_information():
    review.create_index([('text', TEXT)])
    
    
list(review.find({'$text': { '$search': 'disgusting horrible horrid gross bad hate' }}))
# Out:
# [{'_id': ObjectId('636d7d3d4d219422e18d0364'),
#   'review_id': 'krq3bpnkzax-zPJb2F-t3w',
#   'user_id': 'EDW_1sreEpEIeH8bv7ZVTA',
#   'business_id': 'pc1PkDBggUSNU73jONdqHw',
#   'stars': 1.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "I had been coming here for years, but Habana's has lost it ways. The food was so bad and expensive.  Bad food that cost a lot leaves you feeling more than a little ripped off.  The drink menu does not have prices,  this is because a glass of wine is 10 dollars.  The $23 Lechon Asado could have been mistaken for bad jerky.  \nThere are NOW much better Cuban here in Austin, let this one fade away.",
#   'date': '2018-09-14 02:22:00'},
#  {'_id': ObjectId('636d7d434d219422e18d1f15'),
#   'review_id': 'vcBpKpXCo8PfTO2zyNGHew',
#   'user_id': '-AQJpJ_KBODqFbeQKMatxw',
#   'business_id': 'vSdIvXC4hoowKWrHyUOGaQ',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I don't have any idea why but my coffee was so bad I couldn't drink it. The same dark roast I order at other nearby locations and love yet so bad here. I thought it could be a one bad day thing so I gave it another try and got the same horrible results. When your morning starts with coffee you can't drink you are in for a long day. I can only guess that employees didn't make the coffee as ordered or else they are using water from Lake Apopka.",
#   'date': '2017-04-19 23:33:07'},
#  {'_id': ObjectId('636d7d3f4d219422e18d0a88'),
#   'review_id': 'WVpJiCYPXheRHm9tnckApA',
#   'user_id': 'SbRnWwJ1xPxeeSS7j9BJIQ',
#   'business_id': 'zyr68M7lzjC8iAk-c_RQdg',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "The food was good but Worst service I ever had! \n\nWhen I say bad I mean bad!!!!\n\nI had to get our menus, silverware,and remind them we ordered drinks.\n\nWe were there for like two hours. The waitress kept apologizing it's just a crazy night. There were only maybe three tables. We would watch the waitress just stand there.\n\nIt was so bad I almost wanted to ask her if she liked her job? \n\nShe looks just miserable. she was very rude and very lazy! \n\nWhen I finally just ask somebody else for a side of ranch that person just looked at me like they didn't know English! \n\nI finally just said you know what never mind paid for everything and just left!\n\nThere's a big difference between being busy and being pure lazy!",
#   'date': '2014-05-26 03:15:00'},
#  {'_id': ObjectId('636d7d3d4d219422e18d032d'),
#   'review_id': '9wASrSWLJny2qDVkaT8pgQ',
#   'user_id': 'LcXhCl0OEWJQ_b0785j4iQ',
#   'business_id': 'N9f8XoP3Q019I2ph6-_aLA',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Great atmosphere and packaging... but the cupcake tasted really bad and the frosting even worse!\n\nI was very excited to try Sweet after it opened and the very cute atmosphere gave me hope that I would be in for a treat.  I got my cupcakes to go and I was immediately enamored with the boxes and packaging.  However when i got home and actually tried the cupcakes I was sorely disappointed.  The cake was dry- really, really dry.  Stuck in my throat and felt like sandpaper dry.  The frosting, by contrast was sweet- really, really sweet.  Cloyingly sweet- really quite unpleasant.  I ended up throwing 1/2 of each away- it was really that bad.  \nI think they have a great concept that is very on trend, great packaging and store design, a great location and a customer base who will pay through the nose for a cupcake- but honestly... it isn't all about marketing!  You have to have cupcakes that actually taste good... or at least are not objectionably bad!  I am not sure how they are going to make it... I hope for their sake they figure out how to actually make a product that people will enjoy eating!",
#   'date': '2010-03-13 00:38:42'},
#  {'_id': ObjectId('636d7d414d219422e18d12e6'),
#   'review_id': 'KHHfTYG-4eVbFllMlPlBFQ',
#   'user_id': 'Oc5BoHKRvWT3lOqYrUtkcQ',
#   'business_id': 'X7fLdR3A_0hJCBqv3-7O-A',
#   'stars': 2.0,
#   'useful': 4,
#   'funny': 1,
#   'cool': 0,
#   'text': "First the entrance makes no sense.. Before you get to the hostess table, there's a room with tables and guests dining.\n\nThe waiter is pretty friendly and knowledgeable of the menu. He is a little heavy on trying to get some wine at the table, but this is expected with fine dining. He proceeds to get our drinks and informs us we will be getting bread soon. Comes back and takes our app order, bread still on the way.. Comes back with the appetizer and still no bread. I don't want the bread, but it's just poor management if you cannot bring bread to the table before apps. (Yes, I used to be a server)\n\nCalamari - It is delicious but it is not your typical calamari. It is served under an Asian slaw with no dipping sauce.\nJumbo Crab Cake - This is definitely jumbo, and definitely crab. It is one large patty with a TON of crab. This was also very good and the roulade it is served with is not bad at all.\nTempura Lobster Tail - This was good, and I am pretty sure they left it on the shell so we had no doubt that it was worth the 33 dollars. I would rather get the lobster boiled but the appetizer just came fried.\n\nPanko-Crusted Halibut - this was the special and the fish itself was fresh, but the flavoring was on the bland side and not enjoyable\nBone-in Filet - asked for medium and got medium-well. It was dry and lacked flavor.\nFilet - not bad, but was nothing to write home about. I can make this better with the right cut of meat.\nAhi-Tuna - this definitely lacked flavor, but then again the person who got it wanted it to be medium. If it is sushi grade tuna I would do medium-rare or on the rare side. I won't dock points because of flavor.\n\nI expected way more from a fine steakhouse.. They had great appetizers but bad entrees. Step up your game please.",
#   'date': '2013-04-10 18:42:20'},
#  {'_id': ObjectId('636d7d3d4d219422e18d031f'),
#   'review_id': 'jUmSVidkuXT9q-TH3FZO6A',
#   'user_id': 'LZLTN6KxDEsJHEOJBgL-EQ',
#   'business_id': 'tbR3eFhZ9rr06tJDvO2pjw',
#   'stars': 1.0,
#   'useful': 2,
#   'funny': 1,
#   'cool': 0,
#   'text': "I love massages, good massages that is. And a good massage requires a good therapist who listens to their clients. Which, unfortunately for me did not happen! \n\nI think the worst part of a bad massage is that you're all too keenly aware of that bad massage for every minute your are paying for! And you're literally counting down the minutes until it ends, which is completely counterproductive to your reason for getting the massage in the first place.\nI tried the introductory massage for NINETY minutes. Had this been a good massage, I would have been happy. I would have been ecstatic! But within minutes of my 90 minute massage commencing I knew it was going to be a bad massage.\nI had filled out a questionnaire prior to my massage session in which I Circled target/problem areas that I wanted to have addressed, particularly my neck, shoulders, and upper back. When I met my therapist, he read my form and confirmed these specific areas with me.\nBut the bulk of my ninety minute massage was not targeted at the three areas I had requested. Instead, my therapist decided to give me the massage HE wanted to give. During my session, I repeatedly requested that he cover these areas in lieu of the other areas he focused on, mainly my arms, hands, legs, and feet.\nThis was a very looonnnggg massage...which usually is a good thing, but in this case just proved to be frustrating. I couldn't wait for it to be over.\nI literally ran out of the room when he said it was over. When the lady at the front desk started talking to me about memberships I was not interested in being here for one more minute.\n\nOn a side note regarding employment: My dear friend worked here in sales for a brief stint which is why I tried the place in the first place. He endured an injury on the job and could not walk or stand as a result of the injury, which made performing his job duties here impossible. Short story shorter...they fired him, refused to communicate with him, and never paid him his last check. \nThis place has a VERY high turnover rate, which speaks for itself. They literally have employment ads on Craigslist every day!!",
#   'date': '2014-04-01 03:28:32'},
#  {'_id': ObjectId('636d7d414d219422e18d11c2'),
#   'review_id': 'DnkrUmntXxlbz0B7WicjQA',
#   'user_id': '5UIMJ33ysodJ0MOUUq6rzA',
#   'business_id': 'w6OVXlNqhmy3zYj-3q26Yg',
#   'stars': 1.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "Service was awful food bad and poor quality.  Dirty, messy table, greedy female server trying to push higher cost menu items.  Went in around 1pm on a tuesday, based upon reviews, thought place was going to be packed, not one single table with paying customers, just 2 employees sitting at one of the multiple tables in the back partvof the restaurant, and 2 other people arranging tables and walking back and forth. Finally, after 5 minutes, the greedy server came around to take our drink order, some of us order iced water, some coke, and sprite, and my son order a lemonade, which after 3 minutes, she told us they where out of.  She offered him either a coke or sprite, which he rejected, and asked instead for a glass with iced water.  After 5 minutes, SURPRISE, he had a lemonade on the table, or at least looked as one, but no it was a flavorless glass of water with lots of sugar in it. Now, going to the food, dumplings were delicious, eggroll tasted like frozen food boxed one, sweet and sour pork was crappy, crispy beef was great, walnut shrimp was ok, about a B+, chowmein and fried rice were lousy, flavorless and warm, not hot as they should.  When the check came, I don't understand why they impose you a 18-20% tip already included on your bill.  I don't know if you agree with me, but why should you tip that much for service that was bad, and when the server doesn't do a good job according to your expectations and in turn tries to push items that increase your check, so that she can pump up her 20% tip that she didn't deserve.  Tips are deserved with the quality of your service: terrible service = no tip, bad service = no more than 10%, ok service = upto 15%, great service = 18% up to no limit.  Again, tips are worked for, not imposed.  \nDo not waste your time here, look for a better option if craving Chinese or try some other type of food.",
#   'date': '2015-07-16 14:52:32'},
#  {'_id': ObjectId('636d7d404d219422e18d0de1'),
#   'review_id': 'TM0UkSnJMMNOlethACN9Pg',
#   'user_id': 'W69EjU8Xql28ijZITGX0oA',
#   'business_id': 'iyqCE9U3UNDOra_5iwjUIQ',
#   'stars': 1.0,
#   'useful': 3,
#   'funny': 0,
#   'cool': 0,
#   'text': "Lucky Plus is a Hong Kong-style cafe restaurant.  I think they recently opened as there were still many bouquet signs in front when I visited with my family.  \n\nThe menu seems to have a wide variety of foods from the simple rice and noodle dishes to the more elaborate like braise lamb hot pot.  The ambience seem nice with the tasteful decor, with good comfortable seating that is not too crowded.  \n\nBut that's where the good side ends.  Our server seemed very rushed to take our order after we sat down (at 11am just when they opened).  She came to our table 3 times in a short span of 5 minutes.  We did not realize why until we placed our order for a couple of appetizer dishes (Hand shredded chicken and 7-flavor deep fried squid) and a couple of entree dishes (Fried noodles with chicken, Mapo tofu rice, Sauteed shrimp).  It took almost 35 minutes until our first dish showed up which seem an eternity when one is hungry for brunch.  \n\nWhen the food dishes showed up at last, we were very disappointed at every dish.  The hand shredded chicken was more of cut-up pieces of chicken with little taste and too many pieces of skin thrown in.  The 7-flavour deep-fried squid tasted bland -- I tasted salty which is just one flavour as I tried to find more flavour.  The fried noodles looked good but lacked anything special (including taste!).  The sauteed shrimps were not well de-veined so tasted bitter.  We all thought what could possibly go wrong with mapo tofu rice?  Well, the mapo sauce was definitely from a jar so that was pretty hard to mess up, but the rice was too hard (tasted like rice left in a refrigerator overnight).  Very disappointed at the food at Lucky Plus!  \n\nTo add to the poor service and bad quality food, we were presented with the same dishes we had already eaten 3 times over!  If the food quality was better we might have taken up their offer!  But we were honestly not interested in more of the same bad dishes.  \n\nWe hope that Lucky Plus is just testing their kitchen process to make improvements and honing their waiting service to provide a more enjoyable experience for their customers.  But they will need to do this quickly as many traditional Chinese clients like myself would not likely go back after the one bad experience.",
#   'date': '2015-12-20 22:30:59'},
#  {'_id': ObjectId('636d7d404d219422e18d0e5d'),
#   'review_id': 'n2iBSRk3R-D3CJ1bbLozEg',
#   'user_id': 'qpNYqzYpdoXzXRxK3tei9A',
#   'business_id': 'kvHrD9Ifzu5Gr8o48cbeBA',
#   'stars': 1.0,
#   'useful': 2,
#   'funny': 1,
#   'cool': 0,
#   'text': "My husband and I have been pleased with hooters wings and had pretty decent service at the last hooters we went to. This one I must say was pretty bad. We had a craving for some crab legs and knew that Hooters had a very good price on them. This one is close to our new apartment so we drove down there and it was pretty crowded as the NBA all star game had started. \n\nOur server brought us out our drinks fairly quickly for the amount of people there at the time. Too bad we found out after she brought the drinks out that they were out of crab legs. I was pretty disappointed but I do understand that it happens, especially in a restaurant that does not specialize in seafood.\n\nAfter we ordered our meal, it came out tasting great and and while it took a bit of time to cook, I could understand. People were clearing out by this time so there were a lot of tables to clean up. We finished our meal within 15 minutes and never heard from our server again.\n\nAfter waiting for the check for about 15 minutes, I figured she might have thought we were still eating...I'm not sure. So I took both of our empty trays and put them on the end of the table. We were seated in a high traffic area so I figured that next time she walked by she would see we were finished and ask us if we wanted to order anything else or just get the check. This never happened. \n\nAfter another 15 minutes, I began to get up and stand next to my bar stool because my butt was going numb and my husband was just kinda looking around. The waitress was cleaning the table next to ours who had cleared about probably about 10 minutes earlier and by this time it was us and only a few other customers in the restaurant so I assumed she would get to our plates next. This never happened.\n\nWithin the NEXT 15 minutes she cleaned up the table next to ours, then started very casually wiping down a table directly diagonal from us, there was a guy sitting there with a drink at a table that was pulled together with this one to support a large party and she began getting flirty with him: Bending over real far to wipe the table, sitting on the stool and playing with her hair while talking to him, and making small talk while my husband and I are sitting here 10 feet away looking at her do this with empty drinks and dishes on the table for 45 minutes now. After this fiasco I had enough and went up to the front counter where another waitress asked me if I needed something and I told her i had been waiting for almost an hour just for my check and then walked out of the restaurant while my husband waited at the table to pay.\n\nShe ended up getting a dollar from us for the tip and an assurance we will never be back. I can understand at hooters the girls work there and try to get large tips out of single guys. I have no problem with this if they men and boys want to be suckers and throw their money at them. What i DO have a problem with is ignoring your other paying customers for ages and making us wait there all night while you are sitting at the table with a customer and acting like you are off the clock. Not acceptable. I've never given any server under 10% for service even if it was pretty bad until now. If I do decide to go back to Hooters it will not be for a very long time.",
#   'date': '2013-02-22 02:35:55'},
#  {'_id': ObjectId('636d7d404d219422e18d0f59'),
#   'review_id': '23paVyr6iGDWF60ckYRapw',
#   'user_id': 'Gq0JNr5c7vDOr8xsCkk6Tw',
#   'business_id': 'C--wIpxJ4j1y01G_raHdbA',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Best Indian food I have ever eaten, too bad I didn't refrigerate my leftovers and they got bad. Delivery was super fast. The delivery driver was so nice. Will definitely come back for more delicious food:)",
#   'date': '2017-06-06 20:14:08'},
#  {'_id': ObjectId('636d7d434d219422e18d1d43'),
#   'review_id': 'Tl0dRQy7fJHa20-GNSP_Bg',
#   'user_id': 'Ozc6J9k8J05sTcpBPUEBWw',
#   'business_id': 'pKW-5mKigIkzDW4kKnFgYQ',
#   'stars': 4.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "Il Piatto is a great neighborhood Italian restaurant near my house.  I've been coming here for years and never had a bad meal.  I really do not understand the bad reviews. I think it's the closest in Portland to the food I ate in Northern Italy.",
#   'date': '2012-03-01 04:32:05'},
#  {'_id': ObjectId('636d7d424d219422e18d1737'),
#   'review_id': 'bOl432nbKjWzgdFq8XgOdA',
#   'user_id': 'vd_S6JVmPDkaENKfZD66ew',
#   'business_id': 'npuvee4nvr0Pw7iNQxUzGg',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Just as bad as any other subway with the added gross out factor of a very sketchy clientele. Bad for the neighborhood too, they intentionally blocked the drive through lane of neighboring cafe Speedboat coffee shortly after subway starting to serve breakfast. Coincidence?',
#   'date': '2012-03-30 04:45:13'},
#  {'_id': ObjectId('636d7d424d219422e18d1a86'),
#   'review_id': 'Y7-1Mpc-llE-muVJy3cm_A',
#   'user_id': '-agihb0a-Ni-OyWuk-4COQ',
#   'business_id': 'WcifFM_LDBX0TARocLU0Pg',
#   'stars': 1.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "Sometimes I feel bad about giving bad reviews but this place is rough.  First of all, there is no ambiance/ decor/ atmosphere to speak of.  It is bleak.  I got a greek salad an I think 50% of it was way past its day.  What I had was probably the worst food I've ever had.  The people there are unfriendly.  I've heard some decent reviews of this place but my experience has soured it.",
#   'date': '2005-07-14 17:27:12'},
#  {'_id': ObjectId('636d7d424d219422e18d1885'),
#   'review_id': 'tp2_aeLPw6Re8o6GsCpvsw',
#   'user_id': '2X0mgwAqgshZCFz05_9YKw',
#   'business_id': 'SFievF-QFiCZu84jCE2vUA',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "There are good greasy burgers and bad greasy burgers, and Mooyah has bad greasy burgers.  They're a mess to eat and you can't get past the massive amounts of grease enough to enjoy the actual food.  I can't help buy feel like I'm walking into a feeding trough for overweight people with no self respect every time I go here.",
#   'date': '2009-05-20 19:05:27'},
#  {'_id': ObjectId('636d7d404d219422e18d1151'),
#   'review_id': 'QoDPEPxZ4JxvvUOfh7w7Yg',
#   'user_id': 'NiieOK-HyqLLi5Uh9KlyoA',
#   'business_id': 's7TOwyWNB9sdaqyz5qGPPg',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': 'Way over priced. Food quality was really bad. Noise in the place was way to loud for any kind if conversation. Took an hour to be seated. Had to send my food back and have them take it off the check. Couldnt eat it. Burnt and tasteless. In summary, too loud, too expensive, bad service, food really really aweful. Would have preferred going to Dennys.',
#   'date': '2015-01-18 14:25:20'},
#  {'_id': ObjectId('636d7d424d219422e18d1766'),
#   'review_id': '_TXZnljhD30_1LbocFpxHA',
#   'user_id': '4Bgq2oCFQ09nbrQuIh5sww',
#   'business_id': 'k834md6xVWTHWQOMoF82Tg',
#   'stars': 1.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "Definitely not far enough away from the bad side of town.  If you are a female and go there by yourself, even in the middle of the day, be prepared to have people think you are hooking and yell out to you.  Not kidding.  Wouldn't go back there to save my life, sorry.  It's pretty but I've seen a lot better, and felt a lot safer.  I honestly don't know what these other reviewers see in it - I must have gone on a very very bad day apparently.",
#   'date': '2014-05-26 02:21:02'},
#  {'_id': ObjectId('636d7d414d219422e18d145b'),
#   'review_id': '8cpIL_UwKPHpRs62MivdUQ',
#   'user_id': '82yI4qN1cLFK-1aL7ijV4w',
#   'business_id': 'z7H7GmFn5UO1UyqHN-aKoQ',
#   'stars': 2.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "Courteous staff.  Very friendly with exception of airport shuttle driver. \n\nDecent room.  Bigger than average.  Bathroom barely functional with crazy big door configuration. \n\nI would have rated higher, but the airport shuttle was ridiculously bad. Hotel is less than 5 minutes away but we had to wait 45 minutes and then argue with the driver to let us on because it was almost full.  Had we not argued it would have been an hour or more.  \n\nShuttle experience bad enough that I can't recommend and won't stay here again.",
#   'date': '2017-02-19 12:45:01'},
#  {'_id': ObjectId('636d7d424d219422e18d16ef'),
#   'review_id': '8Oa6BKGehMS4o9lcaVuhOg',
#   'user_id': 'G8jCxkkuD4qnWLXu8XMxfw',
#   'business_id': '_kxcbnYXiSvJ0yW9uGT-7Q',
#   'stars': 5.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "i LOVE brighton nails. Nha is amazing, attentive, and pays great attention to exactly what you want. Can't find the right color? She'll mix for you or recommend something for your skin tone or event/function. Any other girl there is great, too. They are always accommodating, even when time is tight. \n\nI feel badly for anyone who felt they had a bad experience there. Nha not only knows her customers by name (or at least by face for newer folks), but she remembers details and makes it a point to help you feel welcome.",
#   'date': '2014-05-07 19:47:35'},
#  {'_id': ObjectId('636d7d434d219422e18d1d71'),
#   'review_id': 'WgazKfoOdQrD3rUOU5GWEg',
#   'user_id': 'gQJ3doJ0-wIGNhN2e_w2dQ',
#   'business_id': 'EiG49nLf6uE2P9bAuBQfXg',
#   'stars': 5.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I'll be honest, I didn't really like my lunch, but it's not because it taste bad or anything. It just wasn't the type of lunch that I would like to have. It was mostly sandwich and wraps.\n\nI ordered the pepper bacon BLT. The taste was not bad. I like the taste of the chips. The bacon was crispy and kinda hard. Personally felt like it was kinda salty but still taste alright. Average customer service. I guess they deserve a five star because I don't thinks right to give them a lower rating just because the food is not my preferences.",
#   'date': '2016-03-31 01:21:10'},
#  {'_id': ObjectId('636d7d434d219422e18d1e08'),
#   'review_id': '9JC-HFxnVGmyCDdgPx7A9g',
#   'user_id': 'I-Zg2r1BDPgaol6warxvCg',
#   'business_id': 'vo1MjyIvHbAJ93PasKHIRg',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Sorry this is a no from us. Four of us dined here earlier in the week. Three people couldn't even eat their meals they were that bad. The soup tasted just like a bowl of warm cinnamon, the creamy chicken pasta had so much blue cheese it was inedible. Spaghetti bolognese wasn't too bad. Drinks were good, Moscow mule not served in a copper cup (that's just being picky). Espresso martinis were good. The decor reminded me of the lobby of a holiday inn express. Server was in training but really good.",
#   'date': '2018-02-01 20:55:57'},
#  {'_id': ObjectId('636d7d434d219422e18d1c24'),
#   'review_id': 'EObMjAzw7eyrrxpil-Rk-g',
#   'user_id': 'DBj1vy-1GziF9ZKRhSs0NQ',
#   'business_id': 'mxk0UbRuG2kIgo5U4AyUyQ',
#   'stars': 3.0,
#   'useful': 3,
#   'funny': 0,
#   'cool': 0,
#   'text': "I have been to Thailand a few times and I love the food. We came here expecting better. The food was underspiced in many ways. Not as bad as all the Chinese joints which try to serve Thai but still disappointing. Even my kids were disappointed. \n\nThey also didn't have any nice accompaniments to remedy the situation. Peppers in fish sauce? Dry pepper flakes? Some of the lovely spice pastes, peanuts? Limes and coriander or Thai basil? Nope. \n\nAnd like so many Americanized Thai places, there was quite a bit of sugar in all the dishes. Too bad.",
#   'date': '2013-11-14 14:57:30'},
#  {'_id': ObjectId('636d7d434d219422e18d1c2b'),
#   'review_id': 'WPZ3zTMH-S-WZgLWtOnUbQ',
#   'user_id': 's1sh0bYgI2fxVzsTOJ2qmw',
#   'business_id': 'iiDu_dHw-uB6kR_hVthKEw',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Disappointed to have to come back and write this update, but people should be informed! Their food is expensive, but the quality is usually on par so I don't mind. I got a slice of their red velvet to go ($7.95 mind you for an average sized slice). I should have known it was a bad decision as it was the last slice left in the morning. Most stores have the courtesy and responsibility to throw away/discount day-olds but clearly Jaho does not take that seriously. The slice I got was stale, crusty and it had GONE BAD! Not sure what kind of quality checks they're doing or what training they're getting but it was horrendous. Stick to the coffee...don't get the food.",
#   'date': '2018-09-25 13:03:40'},
#  {'_id': ObjectId('636d7d414d219422e18d1196'),
#   'review_id': 'G4Ojpin440WLQzIHxskYIQ',
#   'user_id': '9K2_ZE6ODL8Ur0SEecph9g',
#   'business_id': '7RO7xuE6FguVbkDK8v0mnw',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Holy S@?T does this place need a makeover.....I walked in there for the first time about 3 weeks ago .....I was so in the mood for a good salad bar and I knew this was where to go.......the salad wasn't bad at all really.....seemed fresh....tasted good.....but the place was dingy and old looking.....like bad......it didn't particularly look clean......the managers office was at the end of the counter with a curtain draped over it.....strange....just a really off atmosphere......didn't really seem particularly busy either.....which makes sense.....with panera around the corner who needs this old show........wrecking ball maybe???",
#   'date': '2013-05-07 03:28:14'},
#  {'_id': ObjectId('636d7d3d4d219422e18d02d5'),
#   'review_id': 'myaxojkonPu4s64HG02SbA',
#   'user_id': 'sidhQlIARSHJyIp6mmiB0w',
#   'business_id': 'FQsIpsHVYuvE8jH5jrE5Lw',
#   'stars': 3.0,
#   'useful': 1,
#   'funny': 2,
#   'cool': 0,
#   'text': "By no means is me giving Habaneros 3 stars a bad thing. This is my go to spot for Mexican food when my family comes to visit me from NY. It's cheap, it's quick and it's surprisingly good. The establishment offers a wide selection of Mexican dinners and combination specials, common in other traditional Mexican restaurants. If you're a fan of Mexican food, especially if you're from out of town just go here and eat. Parking isn't bad, your seated immediately and there is always a table available. Unfortunately there can sometimes be minor communication errors with your waitresses and the staff so make sure to be very clear with what you want when placing your Oder. The food is good, nothing amazing but it definitely hits the spot.",
#   'date': '2016-01-17 05:49:10'},
#  {'_id': ObjectId('636d7d424d219422e18d1994'),
#   'review_id': 'il-6bEvFSedK_7ebqnxddw',
#   'user_id': 'VtpXgckPUbBblj_6MJX93g',
#   'business_id': '9gOBmODi5-XQ0EbIxkx2MQ',
#   'stars': 3.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Decent happy hour...pretty standard $1 off stuff drink wise and a good amount of food options. I ordered the fries, the calamari, and the pulled pork quesadilla. None of them were bad, but I'd only ever order the fries again. The calamari weren't crispy and the quesadilla too greasy for my taste. \n\nService was on the slow side initially, but our server made up for it by comping our two drinks. I could tell this place had a big whiskey selection, and it looked like a lot of wine too, but I am a beer drinker. The beer list was decent, definitely not bad, but nothing special. Prices were good all around. This place is super convenient to where I live, so I will probably be back, but if it wasn't so convenient I probably wouldn't go out of my way.",
#   'date': '2016-05-19 03:52:01'},
#  {'_id': ObjectId('636d7d424d219422e18d1703'),
#   'review_id': 'KzLATzjjxOMMwZL6YOBjXA',
#   'user_id': 'A3Rahgq3ufx81IjbEfAbGg',
#   'business_id': 'LfIf5GBl6gpSi3KZRjAG2w',
#   'stars': 3.0,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': "Short and sweet. This place is average. Don't get me wrong, I love me some dive bars...but this place is alright....just alright. \n\nMalone's is hit or miss. Have been here several times as I live in the area. Can get rather crowded on the weekends - good luck trying to get a pool table unless you come early. \n\nThe drinks are so-so. Every now and again you'll get a decent pour from the bartender. Service so-so. It's either decent or super slow. Food so-so. It's a bar, what do you expect. The wings and nachos aren't bad. Can't say much for many of the other food items. Not a bad place to watch a sports game. They have daily specials of some sort and their drink prices aren't too terrible.\n\nOh, and the karaoke...awful. At least it's in a seperate room.",
#   'date': '2011-08-24 21:37:52'},
#  {'_id': ObjectId('636d7d414d219422e18d1233'),
#   'review_id': 'QsrQPwNUsp2B2jBx0d3Elw',
#   'user_id': 'nK6zJZUDvDlLdbgL_EdI_Q',
#   'business_id': 'NYTxZDV_G3AdC3INltgTpA',
#   'stars': 4.0,
#   'useful': 1,
#   'funny': 1,
#   'cool': 1,
#   'text': "Well 85°C is finally here in Austin. I've been to many other locations across the country, so like many others, I'm glad its here as it finally shores up something that Austin is desperately missing: asian bakery.\n\nThe bread selection here feels smaller compared to other ones I've been to, but its no less fresh. I appreciate them putting the calorie count on the breads. Personal favorites include the boroh almond half moon and the taro. \n\nAs for the drinks, I can't realize advise the tea - it's surprisingly bad that tastes like murky water with equally as bad pearls. I do hear the sea salt coffee is quite delectable though, so stick to their coffee game.\n\nThey have a decent size dining area and good cakes too, so grab a friend and sit down and chat.",
#   'date': '2018-07-17 02:31:19'},
#  {'_id': ObjectId('636d7d404d219422e18d0d5b'),
#   'review_id': '_2zThV78N32S-q1fsVJaWg',
#   'user_id': 'zv7wSFpJKpqfwZd7-8kLSA',
#   'business_id': 'OC5kki_SlY6vB3Lc3-4rDA',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I had to wait 38 minutes for a margarita. It was frustrating to watch so many people who arrived well after me walk away from the bar with their drinks before me. When I brought this to the attention of the blonde female bartender that I placed my order with she told me that she had already given me my drink. After telling her that wasn't the case(she had given a margarita to the group of African American ladies 5-10ft to my right but not to me) she decided I had at some point walked away from the bar which was also not true(the people waiting on me thought I had left during this interlude). At this point she tried to ignore me and assist other customers. It's one thing to be given bad service but it's infuriating to be blamed for the bad service and ignored. It seemed like a nice place but the customer service was irredeemable. I could not in good conscience recommend this establishment to anyone else with this experience in mind.",
#   'date': '2015-10-17 04:42:56'},
#  {'_id': ObjectId('636d7d434d219422e18d1df6'),
#   'review_id': 'OlDQic0WorOujdzWWt6M5Q',
#   'user_id': 'n_h6SZbojYN49_dG_VbtPQ',
#   'business_id': 'ZzZ3ffcKnwQmN827qh1vKw',
#   'stars': 5.0,
#   'useful': 2,
#   'funny': 0,
#   'cool': 1,
#   'text': "I work in between downtown crossing and south station so vision care seemed like the best bet to get my prescription checked. I had been having issues in one eye and Dr. Zide suggested it was simply contact over wear. Low and behold after a week of less contact use my issue was resolved. \nTwo month later I started to get some really bad migraine headaches along with some bad nausea. It all started with me wearing my glasses more often (which i got elsewhere during a groupon). Dr Zide looked at the glasses and discovered that my Pupil Distance was waaaay off which was causing my headaches while working on computers. Again, he was totally right and i've been wearing my glasses now at work without a headache for a full day. This is a huuuuge improvement and I owe it all to the great vision care team! I would highly recommend them!",
#   'date': '2013-10-03 19:37:15'},
#  {'_id': ObjectId('636d7d3e4d219422e18d05eb'),
#   'review_id': 'PRkWiELaY4z7G3RQSu9O5w',
#   'user_id': 'U55yTM82fCahiAN2Fq6UzA',
#   'business_id': '29_JRRkEwThqMMD0b3SiXg',
#   'stars': 2.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': 'I ordered the chocolate delight cake and the ricotta pie for a work event.  Based on the name and how the lady described it, it sounded like a chocolate lovers dream. It looked beautiful. However it was not true to its name but mostly whipped cream with a caramel sticky center that made it impossible to cut neatly. Did not know about the weird caramel center until I cut into it. Would be nice if the website or employee provided a better description. It was a bit embarrassing trying to cut it in front of 30 people as it was a whipped creamy mess so it did not slice well and just flopped. It was not chocolaty at all.  If you love whipped cream this is the cake for you. The name of the cake is very deceiving.  The ricotta pie was pleasant, not great but not bad and not too sweet. No one commented good or bad but silent speaks louder than words. :/ Will not order this particular cake again. Overpriced at $52 for 12 inch.',
#   'date': '2017-02-09 09:12:49'},
#  {'_id': ObjectId('636d7d3e4d219422e18d0782'),
#   'review_id': '7RP_ndpBFj4MK5KqRu-jvQ',
#   'user_id': '7K3QGYDSgT0SPOdwtbOc2Q',
#   'business_id': 'KRNrssbpE1AKo-48BIpdLw',
#   'stars': 3.0,
#   'useful': 1,
#   'funny': 1,
#   'cool': 1,
#   'text': "I went ot Bao Asian Fusion again with my family, and although our entrees tasted good, details made me wonder about the quality/cleanliness of the place.  \nThe water had a funny taste, it might be because of the ice cubes, like sometimes if you don't use them for a while they have that bad flavor.\nWe ordered sushi and also Chinese dishes for each of us.  I wish they'd asked us in what order we wanted the plates. Instead, we got the hot dishes first and then the sushi a few minutes later.  \nLastly, we could not even eat the tiramisu.  Both my daughter and I found it had a strange taste, kind of a chemical taste. It did not look like a Tiramisu either (and I don't blame them, after all, this is not an Italian restaurant), more like a sad little (previously) frozen thing.   \nOverall, the food was good, but next time, if I go back, I'll make sure to ask to get my sushi first, and ask for water without ice cubes (hopefully it will take care of that bad taste.)",
#   'date': '2018-04-04 03:07:40'},
#  {'_id': ObjectId('636d7d3f4d219422e18d08d5'),
#   'review_id': 'yt8wg-sJD1xbpfBlB3n4oQ',
#   'user_id': 'FPug5WolCYh8qrsYXVPEfQ',
#   'business_id': 'NXHW9lTvBYNuf-mWsu8eTg',
#   'stars': 2.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I had been to Finz this summer with my brothers and had the most amazing salmon dish. I'm talking drool worthy best-meal-I've-ever-had dish. So when it came time for my 30th birthday dinner that's obviously what I wanted. I'd literally been dreaming about this salmon! If I were to base this review on that experience it'd be a 5 star, hands down.\n\nThe restaurant wasn't very busy so we were seated right away. Our waitress was very attentive but things came out horribly slow. We got apps and drinks and were done with our appetizers and waited at least 10-15 more minutes before our meals came out. Slow to the point where I thought maybe our meals had been forgotten about. I ordered another drink and by the time I got it I didn't want it anymore slow.\n\nThe food came out and it didn't look quite as I remembered. It didn't taste quite as I remembered. In fact, it was pretty disappointing. \n\nMaybe it was because they had a rehearsal dinner going on, but I was not satisfied at all.  The service was slow, the food was disappointing, the overall experience just left a bad taste in my mouth (no pun intended). It was really too bad because I had talked this place up to everyone and I left crestfallen.",
#   'date': '2015-12-05 02:22:54'},
#  {'_id': ObjectId('636d7d424d219422e18d1981'),
#   'review_id': 'qwgonY61-DmVq4RPvmCZNQ',
#   'user_id': 'X8JgStOi2YaDszLieV1_9Q',
#   'business_id': '2pkcNQ-ryDiVYGyq4px0_w',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "This is a super bad barber shop, and the hair is dyed garbage! Color is a paragraph! Terrible! Upper half color, the bottom half completely no color! My scalp is full of color, tell me to go home and wash it! Even so, hair dye is a mess, hair root is all not color is the color of bleaching agent! White! Terrible! The bleaching agent is all over my face, not to help me get rid of it in time! Two of them almost fell into my eye! I don't care! I'm used to being stupid! I'm not coming to this store again! I will tell all the people around me not to come! Avoid the same terrible experience! The barber asked me to send her hair take to him, I did, I asked how long will it take to get the barber, he said 3 hours, I said so many years of experience in dyeing tell me at least 5-7 hours, he said no, the results gave me a 9 hours!!!!! Terrible! Nine hours is not the point. The point is to make a mess of my hair. I don't want to go out and see people! Bad mood!! Junk shop!",
#   'date': '2018-03-03 23:38:22'},
#  {'_id': ObjectId('636d7d424d219422e18d16e2'),
#   'review_id': 'sfZCRJGO6BLwuaBYYaEDCQ',
#   'user_id': 'oS1uVWQfsymIbcWcl9c7Lg',
#   'business_id': 'WgFwQLdOZAYeRLbjuky19w',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 1,
#   'cool': 0,
#   'text': "I'll admit that I'm very picky when it comes to nail salons, but this place gets the award for worst manicure I've ever received -- ever. The first time I went there, they did a good job, so I decided to give them another shot. Big  mistake. \n\nI went with my mom, whose manicure was finished first. The technician cut her very badly -- we're talking huge red gash on the side of her nail. No apology, or even acknowledgment. She also asked for square nails and got round ones. \n\nWhen it was my turn, I specifically asked the technician not to cut my cuticles. She did anyway. And boy, did it hurt. She seems to have completely cut my cuticles off on each of my toes, leaving tiny, painful cuts on every single toe. Two days later, it still hurts. The manicure was even worse -- the technician managed to cut me with the filing board. That's a first -- didn't even know you could cut someone filing their nails! My nails are jagged and uneven, and the polish is globby. When I get a less than stellar manicure, I usually just put up with it, but this one is so bad that it's embarrassing, so I'm going to have to get someone else to fix it.",
#   'date': '2013-10-24 14:35:09'},
#  {'_id': ObjectId('636d7d414d219422e18d132b'),
#   'review_id': 'rfIr0O8EaKmL1NykBun6hw',
#   'user_id': 'sHIdY9tgLkVJwZgNZBNDpw',
#   'business_id': '4UHtWgVmvF5igBuAxEeppA',
#   'stars': 3.0,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': "The king size room was nice enough. It had a king size bed and pull out couch and seemed quite clean.  The wallpaper was peeling a little and the carpet seemed a bit worn but other than the usual wear and tear one expects, it wasn't bad. \nThe air conditioner in the room at the Crowne Plaza, was on non-stop for the duration of their stay.  The thermometer reached into the 90's for most of the visit and maybe the high temp contributed BUT the ac worked intermittently for all 3 days of their stay.  Also, there was a weird odor emanating from the ac.  To be blunt, the air coming out of the ac smelled like terrible flatulence.  My sister and her husband didn't complain to the front desk and get a change of room  so I have no idea if this issue was restricted to their room or not.  All I know is that it smelled pretty bad and was not coming from anyone INSIDE of the room.\nFYI: The Crowne Plaza DOES NOT have it's own pool or gym. Guests are able to swim at the pool run by the gym who co-shares some of the hotel space.  For $5.00/hr a hotel guest can swim to their hearts delight...\nAnother FYI: My sister and I had breakfast at the hotel restaurant which she billed to the room. Total cost of breakfast $233.00 and we are still dealing with the billing department to get this resolved...",
#   'date': '2010-07-07 16:19:03'},
#  {'_id': ObjectId('636d7d404d219422e18d0f56'),
#   'review_id': 'qbqRZsmCdfcTHVQObozVww',
#   'user_id': '32r7y1MGHu5V1J4jlBHKPw',
#   'business_id': 'bf9RVPn5IRVgFoXZq4k7gQ',
#   'stars': 5.0,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': "we loved this place. very unique. my kids all under 7 enjoyed the talking moose and the popping raccoon over by the fireplace. moose was giving cheesy jokes but my kids really enjoyed it and kept them from going crazy and throwing their usual tantrums. came w/ free warm bread and butter to start you off while your waiting. the food we ordered was delicious. i ordered the ribs w/ 2 sides..baked beans and seasoned fries. loved everything. kids also enjoyed the ribs and my 1 year old loved the baked beans. my husband ordered the meatloaf w/ 2 sides. we also loved that. very tasty and hubby claims it's the best meatloaf he's tried. it tends to get overly sweet in the end since it's smothered w/ sweet bbq sauce but it was still delicious. wait time for food was surprisingly fast but then again we did go on a weekday. only problem we had (but wasn't a big problem) was the waiter never refilled our drinks and water till we had to ask., which was in the end when we were about to leave. price isn't too bad...ordering 2 items each w/ 2 sides and 1 adult drink and 2 kiddie juice..total came up to a little over $40 which isn't too bad. overall a great experience and can't wait to go back for the delicious food.",
#   'date': '2007-05-18 04:17:50'},
#  {'_id': ObjectId('636d7d414d219422e18d1475'),
#   'review_id': 'mMpOOBYjvI4ABBpRWw3vAA',
#   'user_id': '_djhTlQ47NqNV4phAIGDTA',
#   'business_id': '5J6gpko-pn8XGzlFwCpoWA',
#   'stars': 3.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "Mix feeling about this place. This was a 2nd chance. 1st time bad service. Poor set up to order (still the same) but good food but the flavorless flaw out lobster. \n\nThis time they are willing to run your credit/debit card to pay for the meal, the cashier said I could come back after eating to leave a tip. Still a bad set up. Ok THE FOOD now:\n\nOrdered Lobster roll and Whole belly fried claims with one of my sides being onion nuggets. 4 months had the nuggets, love them, it was a hunk of onion in the middle. Now I got small onion rings. I thought I got the wrong thing. But I was told nuggets are small rings and onion rings are big rings. So they changed. \n\nThe whole belly fried claims were great!!! Hard to find whole belly's. Yum!! \n\nThe sides are good the beans, potato salad, coleslaw. The small onion rings did taste good. \n\nMy lobster roll had no flavor!!!!!! Right color of lobster right texture of lobster. It was like eating air with just no flavor whatsoever. I grew up in Maine so this was A Big Disappointment. Had ice crystals in it. \n\nThey did take it off the bill since I had only two bits. So they handled it good. \n\nThey need to change the way you order. If they did, they could add more tables. \nTables turned equal $$$ for the compant",
#   'date': '2014-11-30 03:34:49'},
#  {'_id': ObjectId('636d7d3f4d219422e18d091f'),
#   'review_id': '3LGLQE6As2JL1CeCuiRkBw',
#   'user_id': '9FrjysHHYEEtp5Y0jqLE1w',
#   'business_id': '2faLQhuvFdk-fHAg9lWXeA',
#   'stars': 3.0,
#   'useful': 0,
#   'funny': 1,
#   'cool': 1,
#   'text': "Banzai was the first place I ever had sushi in Austin, and it's truly a-okay. Let me say, though, that when I come here now, I don't come here for the sushi. I'll say right off that bat- don't have the rolls. Even for the price, they are not worth it. They are obviously pre-made and refrigerated, and they're probably not what you're in the mood for anyway (you won't find anything fresh-made, nothing hot, nothing deep-fried, nothing fusion- just the basic regulars, pre-made and retrieved from the fridge when you order it). Back when I first started coming to Banzai I only ate nigiri, so I didn't know how bad the rolls were. Don't get me wrong, they won't give you food poisoning or anything- they're just not good. The nigiri, though, is decent, if a bit over-priced for the portions. It's great for a quick bite though- the service is decent and fast and the servers are friendly. I also LOVE their bento boxes- they're a really good deal and delicious, especially the salmon one. You can also get an assortment of those Japanese fad drinks, which I like because you can't get those at most other sushi places. The tonkatsu is also good- with pork the way I like it, as opposed to with chicken the way it's offered at almost every other Japanese place in Austin. The lunch specials are okay- they give me the same pre-made and thawed impression I get from the rolls, but they aren't bad tasting, although the portions are a little small. Overall the place is decent. Not worth going out of your way for, but if you know to avoid the rolls you won't leave unhappy.",
#   'date': '2010-11-22 14:27:32'},
#  {'_id': ObjectId('636d7d404d219422e18d0d4d'),
#   'review_id': 'H89gXYYZzW7uZVh8iGH5SQ',
#   'user_id': 'CNaHLXC45cR07vtDeFYeww',
#   'business_id': '0BGoel6on7yGvojzOqOEAQ',
#   'stars': 3.0,
#   'useful': 1,
#   'funny': 1,
#   'cool': 2,
#   'text': "Tiffins is an upscale restaurant located in the middle of Disney's Animal Kingdom.  We were excited to eat here before trying to catch the Rivers of Light show.  \n\nOur dinner reservation was at 5:40 since we were trying to catch the 8:45 show. Unfortunately we arrived about 20 minutes late due to the bus running late.  Fortunately they were able to accommodate us.  The inside of the restaurant is really nice, each room is a different art gallery dedicated to conservation.\n\nI figured that still arriving at 6 would be plenty of time for the show but for some reason the hostess had us wait.  This was strange since it was very empty.  15 minutes later we were seated.  \n\nHaving been on safari in Africa I was excited by the menu as it had a lot of exotic meats.  We started with the charcuterie platter as a starter. I went with the duo of venison which had a venison filet and boerewors (South African sausage).  My wife went with the SA lobster enhancement and the Gobi cauliflower.\n\nI would say i was a little disappointed by the platter and my entree.  The starter was very small and the vension and sausage were not bad but served cold.  I will say that the lobster was amazing and so was the Gobi.\n\nI think the worst part of the restaurant has to be the service.  From the lackadasical hostess to the waiter which took FOREVER for dinner service unbelievably we did not make the 8:45 show.  On top of that it was one of our pricier meals that weekend.  \n\nOverall this place is definitely nice and the food isn't bad.  I think the exorbitantly long service and price make it just Ok for me.",
#   'date': '2018-04-27 20:17:44'},
# ...
#   'date': '2010-07-07 23:01:10'},
#  {'_id': ObjectId('636d7d404d219422e18d0e48'),
#   'review_id': 'lrehcd0o6Qn3UGowf4SiWQ',
#   'user_id': '85EI4HGFJURnRUWQtqs2zw',
#   'business_id': 'Lg7aBaURc2MiAhM4ZJldvQ',
#   'stars': 1.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "LIPSTICK on the PIG - Don't waste your $$!!\n\nThe most horrible experience I have ever had at any resort. We stayed with two boys (10 and 6) and were impressed with the pictures on their website. Below is the experience: \n\n(a) Switch and Bate: The room we got was much older and dated than the one in the pictures. And the check in process was 45mins.  \n\n(b) We found ants in the kitchen and bathroom, they sent pest control, we get back and the ants were still there. The room was directly from the 80's, the worst decorated room I have ever paid $200 per night.  \n\n(c) They moved us to a different room the exchange process took 3 hours. At one point we were waiting on the street for 45mins for the bellman who was getting new keys. He came back informing us that 3-4 kids were stuck in their room because another guest locked an common door (maybe take the lock off?) \n\n(d) When checking out they miscalculated our discount and we had another 20mins wait till the manager finally resolved the issue. \n\nHonestly for 200 per night, you can do much better. I am going to call their corporate offices on Tuesday (5/27/14) let's see what they say! The four/five stars are fake or paid stooges!",
#   'date': '2014-05-25 21:28:00'},
#  {'_id': ObjectId('636d7d424d219422e18d1b4a'),
#   'review_id': 'BeR10KxXEa0e4VsnBAVTcQ',
#   'user_id': 'CqjXHpSHKpAz07zHwe3hzQ',
#   'business_id': 'mxjVk5rvPNhzYe_vt3OSQA',
#   'stars': 3.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "As a party of 1, I showed up at 1245 and sat at the bar.  Situated in the basement of a brownstone, the place is quaint, with a contemporary feel as well. It had a bit of an upper class elite feel to it, but then a lot of downtown Boston does doesn't it?\n\nI had my order within 2 minutes of sitting down: 6 oysters, a small cup of chowder, and a lobster roll.  The waitress asked how I would like them to come out - oysters first and the chowder and lobster together. \n\nThe oysters were out and eaten by 12:55. They have a terrific selection of oysters to pick from.\n\nThe chowder came next. It was very good, but perhaps a very small amount. It did not come together with the roll unfortunately.\n\nAt around 1:30, the lobster roll came out. This seemed a bit excessive; The place did start to fill up AFTER I had arrived. The Lobster roll was good, not amazing.  The fries, pickles, and slaw, that came with them, very average - The fries being a bit too long in the fryer.\n\nI'm not a Bostonite so I am unsure if the meal was costly.  The $60 meal was perhaps a bit high, but not horrible. The place was packed at 1:30 on a Monday afternoon so perhaps it is normal. However, I had the Lobster Roll at Legal Seafoods at Logan Airport last week and it was the same price($29), and was actually a bit better. I would expect to pay less than airport prices in town.",
#   'date': '2016-04-11 19:34:19'},
#  {'_id': ObjectId('636d7d3e4d219422e18d07b3'),
#   'review_id': 'X9YHyfRReD-Ot6_zF19kFQ',
#   'user_id': 'UsA79vSfHW0jkmeN0Y5pWQ',
#   'business_id': '9lfndCYryaRMpc9uOoP9GQ',
#   'stars': 1.0,
#   'useful': 2,
#   'funny': 1,
#   'cool': 1,
#   'text': 'WIll not be going here ever again.  Went out with friends for dinner here and were super excited to try it out.  We put our names in and were told it would be about 20 minutes.  After waiting for about 40 minutes we asked the host what was going on?  He explained to us people were not leaving etc.....he finally got us a couch to sit at while we proceeded to wait another 30 minutes for a table of 4. The service was so so poor.  Finally the host told us how sorry he was and he would give us complimentary dessert.  We felt better that as least they understood we had waited forever.  We sat and our server again apologized to us about how long we had to wait and reminded us about our free dessert more than once.  The food was sub-par to say the least.  The restaurant was SUPER loud because of the wedding going on next door and the bridal party kept running in and out of the restaurant getting drinks at the bar.  After we finished dinner we decided we would just order 2 desserts to spit between both couples.  When we ordered the two $6.00 desserts the waitress proceeded to tell us that we would only be getting one dessert free!  Needless to say, horrible customer service and not very bright wait staff, the least she could have done was go ask if they could comp our $12.00 worth of dessert that they had reminded is 4 time that we would be getting. Very upsetting and disappointing night.',
#   'date': '2011-09-25 18:47:49'},
#  {'_id': ObjectId('636d7d424d219422e18d1733'),
#   'review_id': 'z8HC1-IzROrT97PEj9XDvQ',
#   'user_id': '2W6Py3QEejquTs47JeALxg',
#   'business_id': 'VMIxEOpNQgOYU7xTkGR6TA',
#   'stars': 1.0,
#   'useful': 2,
#   'funny': 0,
#   'cool': 0,
#   'text': "I pulled in to this Firestone tire center in Orange City Fl.  because I had a tire going flat and needed to get it fixed, It was 6:00 pm an hour before they close. I waited for about 10 minutes before the manager Chris came in and the first thing he said is we are not taking anymore customers. I said but my tire is going flat and needs repaired. again he said we are not taking anymore customers. Now there were other customers there and I realize they would come first, but all he had to say was i have people ahead of you but i will get your tire fixed since its going flat.( aka customer service).  Luckily there was a tire Kingdom around the corner and they were cleaning up and getting ready to close for the night. They said no problem we will fix it for you. They jumped right on it and fixed my tire which had a 4 inch bolt/screw  in it and they had to take the tire off the rim to fix it. They never once complained and were so much more professional. Come to find out they had a special and it only cost me 11.50 to fix it. I would not recommend going to Firestone in Orange City Florida. Their customer service is horrible and that is because of their Manager Chris. i will be calling corporate and making a complaint against This store and the Manager. I am also a retired Fire Fighter and  I know a lot of fireman and their family's in the Central Florida area that always need car work done. I will be spreading the word DO NOT go here. Take your business over to Tire Kingdom in Orange City where they treat you like a human being and are very Professional.",
#   'date': '2017-09-09 01:00:03'},
#  {'_id': ObjectId('636d7d3e4d219422e18d07dd'),
#   'review_id': 'lygWO5cs_pnKIiEWlV9FzQ',
#   'user_id': 'JXOrtshU-xeKfqc5ce87ig',
#   'business_id': 'rbe6cBtApDk9YXDphP1XHg',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "I've been to this location a couple of times, the service has never been great but I've come back for the good food. This time both the service and the food were absolutely horrible. My husband and I were starving and came in for a late dinner after a day of work and events. After I was seated first and waited for him to arrive, I ordered a cocktail that took about 15 minutes to arrive and it also took me asking (literally) 5 times to receive a glass of water. I'm pretty sure this was our server's first night on the job as he was incredibly awkward and forgetful and did absolutely no bussing unless we asked him to clear things. We ordered 2 appetizers, the firecracker shrimp and the trout dip. The trout dip was tolerable, but had an overwhelming mustard taste that drowned out any other flavor. The firecracker shrimp tasted like something from a cheap Chinese restaurant and was served with jarred chili sauce and a sickly sweet mayonnaise. Then came the entrees... which took us having to flag down our server long after we had finished our appetizers to order. His turkey meatloaf was decent though nothing spectacular. My barramuni was inedible. I don't know how a piece of fish can be simultaneously oily and dry. Not only that, it was completely unseasoned, but I still found it bland after adding salt and pepper. The fish was supposed to come with quinoa, squash and green beans. Underneath my disappointing piece of fish was maybe 2 tablespoons of quinoa and some mushy squash. This wouldn't have been a big deal if it hadn't taken so long for our server to check on our dishes, and then if a manager had come by in a timely manner. Instead we had to yet again flag down our server, and then when he seemed confused about what to do, we had to ask him to send over the manager. Even after taking my entree off the bill I was furious to have spent $50 on such a disappointing experience.",
#   'date': '2016-04-11 19:58:31'},
#  {'_id': ObjectId('636d7d3f4d219422e18d09b5'),
#   'review_id': '--5hj5BxUDVfW651eyRU_w',
#   'user_id': 'prmFsAhjHwCb1NC6MmNBCg',
#   'business_id': 'p2BkIrOuIsxGqtV0lwOZUw',
#   'stars': 1.0,
#   'useful': 7,
#   'funny': 1,
#   'cool': 2,
#   'text': "The one star is not for their food. I ordered a laffa shawarma and it's solid. The one star is for their horribly rude service. \n\nI was picking up my boyfriend from KSM last night (Mar 17), walked in close to 8:30p not expecting any of the food stalls to be opened. The lights were still on at Yalla, three behind the counter, with two prepping food for a customer and one woman  standing behind the cashier. There was no sign of closing down/wrapping up/adding up receipts, etc. I asked if they were still open and she said yes. When ordering, I asked her if the shawarma has lamb as it's not specified on the menu, she was curt and said chicken. I told her i want hummus in the wrap and she rudely told me I needed to move down the line and to tell that to the second server when there's no one waiting behind me. The second server (woman) gave me a blank look and proceeded to ask me whether I want each of the ingredients in front of her one by one (now I get why the service is so painfully slow per other reviewers). There's no list of those items on the menu or anywhere visible to the customer when ordering (that I can see). It was my first time at Yalla so I wasn't familiar with what they have. KSM is an open space so when it's not packed, there's echo. The girl was very soft-spoken so i had to ask her to repeat and speak louder when she asked me those questions. She got more annoyed and rude to a point that I just want to walk away. I actually wasn't the last customer, they took orders from two other after me.\n\nPoint of the story is, I understand that it's end of the day and you were supposed to close at 8:30p, that was why I asked if you guys were still open. The second you said yes, you had committed to deliver. If you were going to be rude and act annoyed (i'm actually making a generous assumption here that the two women were rude because it's end of day and it's not because of their personalities), then don't say yes; apologize and said you were closing, I would have come back next time I am at KSM. BUT, with this experience I will NEVER buy from Yalla again.",
#   'date': '2015-03-18 18:34:26'},
#  {'_id': ObjectId('636d7d424d219422e18d1a4d'),
#   'review_id': 'nqIcT4tGpDL6XnF7MwJJqg',
#   'user_id': '-zRXq6_a3JrzZSZ2sWCVrw',
#   'business_id': 'OMF9EFdNGGL14cn7x4nk4g',
#   'stars': 2.0,
#   'useful': 9,
#   'funny': 0,
#   'cool': 0,
#   'text': "Manfriend and I were absolutely giddy on our way here for dinner. I'd read just about every yelp review for this place--I could probably recite the menu from front to back since I'd looked it up so many times. \n\nThe manfriend's dad is in the wine business and wanted to treat us with some awesome food so we were to meet him and his wife for a 7pm reservation. We were there at 6:30, and needless to say: it was PACKED. A lovely bartender saw us trying to avoid traffic and immediately asked if she could get us anything. Two glasses of pinot noir coming right up! The bartenders did an amazing job keeping track of the order people came in so they could point them to seats as soon as one cleared up.\n\nManfriend's Poppa and Momma bear came promptly at 6:45 to check in, only to find the reservation was at 7:30 pm. Momma bear promptly pulled up a voicemail they'd left with her earlier in the morning to show us they'd reminded her it was 7. We were all excited though and continued to dodge the waitstaff as we waited for our new reservation.\n\nOnce finally seated, we ordered the brie and calamari for the table. The brie was a much smaller portion than I expected and buried underneath a mountain of arugula. It was a nice attempt, but all the toppings and dressings washed out the brie. The calamari was delicious--perfectly crisped and battered. The bread of course was to die for. The manager even came by with a plate of bolognese to apologize for the mess up. This was AMAZING!\n\nAfter a bit of a wait (expected since it was crowded), our food came...and it just went downhill. Manfriend's sauce that the salmon sat in tasted like salsa. My medium-rare burger was actually well done. Momma bear's porkchop had a different side from the one she requested and was completely dried out. Poppa bear was also missing a side. We didn't bother waiting for corrections--we'd already been there for 2.5 hours just waiting from start till now. My burger probably would've been good, but I left half of it untouched. A well done burger just isn't a burger anymore. I ordered a drink instead....which also never came.\n\nI was so horribly disappointed by the end of the meal. It's hard to stay mad at the staff since they're actually VERY sweet, but they just didn't handle our dinner service well at all.",
#   'date': '2015-02-16 14:46:44'},
#  {'_id': ObjectId('636d7d3e4d219422e18d0769'),
#   'review_id': '2aZA6wJtY4GMa_EB3LgO7A',
#   'user_id': 'q3UOuSCmcBtg28_x4mbz-w',
#   'business_id': 'zmZ3HkVCeZPBefJJxzdJ7A',
#   'stars': 4.0,
#   'useful': 0,
#   'funny': 0,
#   'cool': 0,
#   'text': "My first taste of pho and I have loved it since. Huge portions for a low cost and tremendous taste. I always order #16 and have never been disappointed. Unexpectedly the wings here are some of the best I have ever had. The only contention I have with Le's is the service can be absolutely horrid and you really have to flag down your waiter/waitress to get service sometimes.",
#   'date': '2018-02-01 20:14:13'},
#  {'_id': ObjectId('636d7d424d219422e18d1a25'),
#   'review_id': 'nNSoPWBi2Vey0_-Mq8B-hQ',
#   'user_id': 'CD-N5vYkLkNE6b5YfhlR7Q',
#   'business_id': '9CUdYtLyfpYeF5S3HbgysA',
#   'stars': 3.0,
#   'useful': 1,
#   'funny': 0,
#   'cool': 0,
#   'text': "Good except for the poor service.\nChecked in for a good meal at half past eight. Orders were taken and then we noticed was that a few items were not available. Instead , we were given another item as an alternative. If this is the way of serving without notifying customer, this is absolutely horrid. Why not say that the item's unavailable instead of giving second rated alternatives?",
#   'date': '2013-11-14 05:32:09'},
#  {'_id': ObjectId('636d7d3f4d219422e18d0b0a'),
#   'review_id': 'Yd8YgWPuy1e9ref2Od2L4g',
#   'user_id': 'SvymdE5dqWs7aZWPEy2cQQ',
#   'business_id': 'rforVL2E1ggE6V5yJMOmDQ',
#   'stars': 1.0,
#   'useful': 0,
#   'funny': 1,
#   'cool': 0,
#   'text': "Worst service ever. Been sitting here for 15 minutes so far. That's right I'm reviewing as I wait. Can't eat my dinner without a beverage. Fries gone quite some time ago. Won't be back. Place is a joke and so was our server. Stay clear people. Didn't get to eat my dinner. It's cold now. Wondering if they will top this horrid experience off by making me pay for food I couldn't eat and drinks I didn't get......waiter is here and yep. He has our bill for us. Insult to injury! Such rubbish.",
#   'date': '2016-12-04 05:16:11'}]

# %%
# We create a text index here
if 'text_text' not in review.index_information():
    review.create_index([('text', TEXT)])

result_1d = len(list(review.find({'$text': { '$search': 'disgusting horrible horrid gross bad hate' }})))

# %%
# Do not delete/edit this cell
pickle.dump(result_1d, open("results/result_1d.p", "wb"))

# %%
grader.check("q1d")
# Out:
# q1d results: All test cases passed!

# %% [markdown]
# ### Question 1e
#
# Now let's learn Mongo updates, deletions, and creation. Create a new collection called `review_boolean` which is the exact same as `reviews` EXCEPT there is a new field called `to_avoid` which is the string "true"  if the review `text` contains the words "disgusting", "horrid", "horrible", "gross", "bad", or "hate" and the string "false" if not.
#
# This is a tricky task! We have not discussed creation, updates, or insertions in great detail during lecture but luckily, Mongo uses a similar approach to SQL.
#
# *Insertions*: In order to insert into a document, you may use the functions [review_boolean.insert_one(...)](https://docs.mongodb.com/manual/reference/method/db.collection.insertOne/) or [review_boolean.insert_many(...)](https://docs.mongodb.com/manual/reference/method/db.collection.insertMany/). These functions take in a document or a list of documents and inserts them into the collection.
#
# *Updates*: In order to update a document, you may use the functions [review_boolean.update_one(...)](https://docs.mongodb.com/manual/reference/method/db.collection.updateOne/) or [review_boolean.update_many(...)](https://docs.mongodb.com/manual/reference/method/db.collection.updateMany/). These functions take in two parameters. The first specifies which documents should be modified. If the first parameter is `{}`, this indicates that all documents should be updated. However, you can put a more specific filter here if you would like. The second parameter specifies what you would like to update your field to (the [$set](https://docs.mongodb.com/manual/reference/operator/update/set/) operator may come in handy here). Recall that in our SQL model, updates are performed as `UPDATE ... SET ... WHERE ...`. In our case, the first ellipsis corresponds to `review_boolean`, the second ellipsis corresponds to the second parameter of `update_*`, and the third ellipsis corresponds to the first parameter of `update_*`.
#
# *Creation*: We handle creation of the collection for you. But in Pymongo, creation of a collection is as simple as writing `variable_name = db[collection_name]` where db is the the Pymongo database object variable you have already created.
#
# Some additional reminders and hints:
# - The empty collection `review_boolean` has already been created for you and is stored in the variable of the same name.
# - A text index has been created for you. You can use a similar search approach as the last question.
# - We want to start by inserting the documents from the `review` collection into the `review_boolean` collection.
# - Don't forget that in order to pass the hidden tests, the `to_avoid` field must exist for every document in `review_boolean`! The [$exists](https://www.mongodb.com/docs/manual/reference/operator/query/exists/) operator may be helpful.

# %%
review_boolean = mydb["review_boolean"]
review_boolean.drop()

# We create a text index here
if 'text_text' not in review_boolean.index_information():
    review_boolean.create_index([('text', TEXT)])

# YOUR ANSWER BEGINS HERE

review_boolean.insert_many(review.find({}))
review_boolean.update_many({},{'$set': {'to_avoid': "False"}})
# for r in review_boolean.find({'$text': { '$search': 'disgusting horrible horrid gross bad hate' }}):
#     r.update_one({},{'$set': {'to_avoid': "True"}})
review_boolean.update_many({'$text': { '$search': 'disgusting horrible horrid gross bad hate' }},
{'$set': {'to_avoid': "True"}})

# %%
len(list(review_boolean.find( { 'to_avoid': { '$exists': 'true' } } )))
# Out:
# 7500

# %%
len(list(review_boolean.find( { 'to_avoid': { '$exists': 'false' } } )))
# Out:
# 7500

# %%
# Do not delete/edit this cell
review_boolean_1e = mydb["review_boolean"]
pickle.dump(list(review_boolean_1e.find({}, {'_id': 0})), open("results/result_1e.p", "wb"))

# %%
grader.check("q1e")
# Out:
# q1e results: All test cases passed!

# %% [markdown]
# ### Question 1f
#
# Now, you had a change of heart: you decide that it's unfair to label restaurants as `to_avoid` without at least giving them a chance! Remove the `to_avoid` field from the `review_boolean` collection. Calculate the `difference` between the data size of `review_boolean` with the `to_avoid` field and without it. The code for making this calculation is provided but it is up to you to actually remove the field.
#
# *Deletions*: Deletions in Mongo make use of the `review_boolean.update_one(...)` or `review_boolean.update_many(...)` functionality discussed in Question 1e. However, this time, instead of using the `$set` operator which allows for the creation of new fields, we will use the [$unset](https://docs.mongodb.com/manual/reference/operator/update/unset/) operator which deletes them! Very tidy!
#
# **Before running the next cell, make sure to re-run your cell for 1e so you don't get a difference of 0!**

# %%
with_avoid = mydb.command("collstats", "review_boolean")['size']

# YOUR ANSWER BEGINS HERE
review_boolean.update_many( {},{'$unset' : { 'to_avoid' : ''}})
# END

without_avoid = mydb.command("collstats", "review_boolean")['size']
difference = with_avoid - without_avoid

# %%
# Do not delete/edit this cell
pickle.dump(difference, open("results/result_1f.p", "wb"))

# %%
grader.check("q1f")
# Out:
# q1f results: All test cases passed!

# %% [markdown]
# ## Question 2: JSON and Relational Models
#
# ### Question 2a
#
# Now we have a good idea of how to do retrieval, aggregation, and updates in Mongo. But we haven't talked about why we
# would want to use Mongo to store JSON! In order to explore this, let's take another look at the `business`
# collection. We will look at the first two entries.

# %%
list(business.find({}).limit(2))
# Out:
# [{'_id': ObjectId('6365c56f01bec29b734e4e9c'),
#   'business_id': '6iYb2HFDywm3zjuRg0shjw',
#   'name': 'Oskar Blues Taproom',
#   'address': '921 Pearl St',
#   'city': 'Boulder',
#   'state': 'CO',
#   'postal_code': '80302',
#   'latitude': 40.0175444,
#   'longitude': -105.2833481,
#   'stars': 4.0,
#   'review_count': 86,
#   'is_open': 1,
#   'attributes': {'RestaurantsTableService': 'True',
#    'WiFi': "u'free'",
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsReservations': 'False',
#    'WheelchairAccessible': 'True',
#    'Caters': 'True',
#    'OutdoorSeating': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'HappyHour': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'RestaurantsPriceRange2': '2',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': True}",
#    'HasTV': 'True',
#    'Alcohol': "'beer_and_wine'",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}",
#    'DogsAllowed': 'False',
#    'RestaurantsTakeOut': 'True',
#    'NoiseLevel': "u'average'",
#    'RestaurantsAttire': "'casual'",
#    'RestaurantsDelivery': 'None'},
#   'categories': 'Gastropubs, Food, Beer Gardens, Restaurants, Bars, American (Traditional), Beer Bar, Nightlife, Breweries',
#   'hours': {'Monday': '11:0-23:0',
#    'Tuesday': '11:0-23:0',
#    'Wednesday': '11:0-23:0',
#    'Thursday': '11:0-23:0',
#    'Friday': '11:0-23:0',
#    'Saturday': '11:0-23:0',
#    'Sunday': '11:0-23:0'}},
#  {'_id': ObjectId('6365c56f01bec29b734e4e9d'),
#   'business_id': 'tCbdrRPZA0oiIYSmHG3J0w',
#   'name': 'Flying Elephants at PDX',
#   'address': '7000 NE Airport Way',
#   'city': 'Portland',
#   'state': 'OR',
#   'postal_code': '97218',
#   'latitude': 45.5889058992,
#   'longitude': -122.5933307507,
#   'stars': 4.0,
#   'review_count': 126,
#   'is_open': 1,
#   'attributes': {'RestaurantsTakeOut': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'GoodForKids': 'True',
#    'BikeParking': 'False',
#    'OutdoorSeating': 'False',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'Caters': 'True',
#    'RestaurantsReservations': 'False',
#    'RestaurantsDelivery': 'False',
#    'HasTV': 'False',
#    'RestaurantsGoodForGroups': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'NoiseLevel': "u'average'",
#    'ByAppointmentOnly': 'False',
#    'RestaurantsPriceRange2': '2',
#    'WiFi': "u'free'",
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'Alcohol': "u'beer_and_wine'",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': False, 'breakfast': True}"},
#   'categories': 'Salad, Soup, Sandwiches, Delis, Restaurants, Cafes, Vegetarian',
#   'hours': {'Monday': '5:0-18:0',
#    'Tuesday': '5:0-17:0',
#    'Wednesday': '5:0-18:0',
#    'Thursday': '5:0-18:0',
#    'Friday': '5:0-18:0',
#    'Saturday': '5:0-18:0',
#    'Sunday': '5:0-18:0'}}]

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# What are **two** pros of storing this data in MongoDB with JSON over a relational database management system such as Postgres?
# Please reference specific examples from the `business` collection to back up your claims.
#
# <!--
# BEGIN QUESTION
# name: q2a
# manual: true
# points: 2
# -->

# %% [markdown]
# 1. Since it does not follow tabular format, it can have flexible shema. For exmaple, the order of ambience's keys  between the first doucment and the second docuemnt are different. This makes it possible because MongoDB does not have fixed set of attributes.
# 2. The key-value format makes more human-readable and explicity explains what data means. For example, by looking at BusinessParking field of second document, 'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}", we can understand what data is trying to say straightforwardly that in "Flying Elephants at PDX", there is a garage and can not park in the street, but not validated info, and etc.

# %% [markdown]
# <!-- END QUESTION -->
#
#
#
# ### Question 2b
#
# It seems like MongoDB is getting all the love when it comes to JSON support! However, modern iterations of relational databases
# such as Postgres 9.3+ also have [excellent JSON functionality](https://www.postgresql.org/docs/9.3/functions-json.html) as we will soon explore in this task. First, let's set up a
# bit of scaffolding. The following cell will import the `yelp_academic_dataset_review.json` data into a table called `reviews` in Postgres yelp database.

# %%
# %reload_ext sql
# %sql postgresql://jovyan@127.0.0.1:5432/postgres

# !psql -h localhost -c 'DROP DATABASE IF EXISTS yelp'
# !psql -h localhost -c 'CREATE DATABASE yelp'
# !psql -h localhost -d yelp -c 'DROP TABLE IF EXISTS reviews'
# !psql -h localhost -d yelp -c 'CREATE TABLE reviews(data TEXT);'
# !cat data/yelp_academic_dataset_review.json | psql -h localhost -d yelp -c "COPY reviews (data) FROM STDIN;"
# %sql \l
# Out:
# DROP DATABASE
# CREATE DATABASE
# NOTICE:  table "reviews" does not exist, skipping
# DROP TABLE
# CREATE TABLE
# COPY 7500
#  * postgresql://jovyan@127.0.0.1:5432/postgres
# 8 rows affected.
# [('baseball', 'jovyan', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('imdb', 'jovyan', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('jovyan', 'jovyan', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('postgres', 'jovyan', 'UTF8', 'en_US.utf8', 'en_US.utf8', None),
#  ('template0',
#   'jovyan',
#   'UTF8',
#   'en_US.utf8',
#   'en_US.utf8',
#   '=c/jovyan\njovyan=CTc/jovyan'),
#  ('template1',
#   'jovyan',
#   'UTF8',
#   'en_US.utf8',
#   'en_US.utf8',
#   '=c/jovyan\njovyan=CTc/jovyan'),
#  ('ucb_buildings', 'jovyan', 'UTF8', 'en_US.UTF-8', 'en_US.UTF-8', None),
#  ('yelp', 'jovyan', 'UTF8', 'en_US.utf8', 'en_US.utf8', None)]

# %% [markdown]
# Now, run the following cell to connect to the Postgres yelp database. There should be no errors after running the following cell.

# %%
# %sql postgresql://jovyan@127.0.0.1:5432/yelp

# %% [markdown]
# Run the following cell to observe how this new `reviews` table looks. Note that the `data` column is stored as TEXT and not as JSON.

# %%
# %%sql
# SELECT * FROM reviews  LIMIT 2;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/postgres
#  * postgresql://jovyan@127.0.0.1:5432/yelp
# 2 rows affected.
# [('{"review_id":"lWC-xP3rd6obsecCYsGZRg","user_id":"ak0TdVmGKo4pwqdJSTLwWw","business_id":"buF9druCkbuXLX526sGELQ","stars":4.0,"useful":3,"funny":1,"coo ... (1757 characters truncated) ... now the former glory to be able to compare. Easy access to downtown Salem without the crowds on this month of October.","date":"2014-10-11 03:34:02"}',),
#  ('{"review_id":"8bFej1QE5LXp4O05qjGqXA","user_id":"YoVfDbnISlW0f7abNQACIg","business_id":"RA4V8pr014UyUbDvI-LW2A","stars":4.0,"useful":1,"funny":0,"coo ... (599 characters truncated) ... g customers for being such a busy store. Located directly in the Framingham Mall on Cochituate Rd / Route 30. 4 stars.","date":"2015-07-03 20:38:25"}',)]

# %% [markdown]
# Observe how the reviews table consists of one column named `data`. This column contains all the JSON documents in the
# reviews collection *in text format*. Use [Postgres' JSON functions](https://www.postgresql.org/docs/9.3/functions-json.html) to write a query that converts the JSON fields into their own `TEXT` columns (hint: one of the operators in Table 9-40 may be useful). To be more concrete, your query should contain 8 columns in this particular order: `review_id`, `user_id`, `business_id`, `stars`, `useful`, `funny`, `cool`, and `text`. Each row should correspond to one JSON document. Some skeleton code (that does the mundane work of converting data to JSON properly) is provided to you - you will only need to fill in the SELECT clause.

# %%
# %%sql result_2b <<
# SELECT b.values::json ->>'review_id' AS review_id,b.values::json ->>'user_id' AS user_id,b.values::json ->>'business_id' AS business_id, b.values::json ->>'stars' AS stars, b.values::json ->>'useful' AS useful, b.values::json ->>'funny' AS funny, b.values::json ->>'cool' AS cool, b.values::json ->>'text' AS text
# FROM (SELECT CAST(regexp_replace(data, E'[\\n\\r]+', '','g') AS JSON) AS values FROM reviews) b
# ORDER BY review_id
# LIMIT 10;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/postgres
#  * postgresql://jovyan@127.0.0.1:5432/yelp
# 10 rows affected.
# Returning data to local variable result_2b

# %%
# Do not delete/edit this cell
result_2b.DataFrame().to_csv('results/result_2b.csv', index=False)

# %%
grader.check("q2b")
# Out:
# q2b results: All test cases passed!

# %% [markdown]
# ### Question 2c
#
# One important aspect of data engineering that we have not referred to yet are joins. We saw, through the use of indices, selection/projection pushdown, and various physical implementations (as well as orderings), joins could be done quite efficiently in relational SQL based databases. How do joins fare in Mongo where the data stored is inherently semistructured? Let's investigate! For this question, we have provided you access to the tables `business_complete` and `review_complete` which contain the business and review collections in relational form as described in 2b (the columns of the relations
# are fields in the JSON document). Each relation has its respective id (`business_id` or `review_id`) column as its primary key.

# %%
# !psql -h localhost -d yelp -c 'DROP TABLE IF EXISTS business_complete'
# !psql -h localhost -d yelp -c 'CREATE TABLE business_complete(business_id TEXT PRIMARY KEY, name TEXT, address TEXT, city TEXT, state TEXT, postal_code TEXT, latitude TEXT,longitude TEXT, stars TEXT, review_count TEXT, is_open TEXT, attributes TEXT, categories TEXT, hours TEXT);'
# !psql -h localhost -d yelp -c 'DROP TABLE IF EXISTS review_complete'
# !psql -h localhost -d yelp -c 'CREATE TABLE review_complete(review_id TEXT PRIMARY KEY, user_id TEXT, business_id TEXT, stars TEXT, useful TEXT, funny TEXT, cool TEXT,text TEXT);'
# !cat data/business.csv | psql -h localhost -d yelp -c "COPY business_complete (business_id,name,address,city,state,postal_code,latitude,longitude,stars,review_count,is_open,attributes,categories,hours) FROM STDIN CSV HEADER;"
# !cat data/review.csv | psql -h localhost -d yelp -c "COPY review_complete (review_id, user_id, business_id, stars, useful, funny, cool, text) FROM STDIN CSV HEADER;"
# Out:
# NOTICE:  table "business_complete" does not exist, skipping
# DROP TABLE
# CREATE TABLE
# NOTICE:  table "review_complete" does not exist, skipping
# DROP TABLE
# CREATE TABLE
# COPY 35
# COPY 7500

# %% [markdown]
# Let's take a look at how `review_complete` looks.

# %%
# %%sql
# SELECT * FROM review_complete LIMIT 1;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/postgres
#  * postgresql://jovyan@127.0.0.1:5432/yelp
# 1 rows affected.
# [('lWC-xP3rd6obsecCYsGZRg', 'ak0TdVmGKo4pwqdJSTLwWw', 'buF9druCkbuXLX526sGELQ', '4.0', '3', '1', '1', "Apparently Prides Osteria had a rough summer as evidenced by the almost empty dining room at 6:30 on a Friday night. However new blood in the kitchen ... (1554 characters truncated) ... t although I personally don't know the former glory to be able to compare. Easy access to downtown Salem without the crowds on this month of October.")]

# %%
# %%sql
# SELECT * FROM business_complete LIMIT 1;
# Out:
#    postgresql://jovyan@127.0.0.1:5432/postgres
#  * postgresql://jovyan@127.0.0.1:5432/yelp
# 1 rows affected.
# [('extrX1RLZEOq6VXN5SvnTw', "Fiskie's Cafe", '27 Harbor Point Blvd', 'Dorchester', 'MA', '02125', '42.318905', '-71.042273', '3.5', '32', '1', '{"BikeParking":"False","NoiseLevel":"u\'average\'","Ambience":"{\'romantic\': False, \'intimate\': False, \'classy\': False, \'hipster\': False, \'di ... (567 characters truncated) ... usinessAcceptsCreditCards":"True","BusinessParking":"{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': False, \'valet\': False}"}', 'Burgers, American (Traditional), Asian Fusion, Chinese, Restaurants, Mediterranean', '{"Monday":"11:0-21:0","Tuesday":"11:0-21:0","Wednesday":"11:0-21:0","Thursday":"11:0-21:0","Friday":"11:0-21:0","Saturday":"11:0-20:0","Sunday":"11:0-20:0"}')]

# %% [markdown]
# At this current moment in time, Mongo only supports left joins (via the lookup aggregation stage). This is what we will compare against SQL.
#
# Let's start by writing a SQL query that displays all the reviews along with their associated business information. You should perform a **left join** between the `review_complete` table and the `business_complete` table on the `business_id` column, and you may project all columns. Keep a mental note of the **execution time** that you see in the query plan.

# %%
result_2c_str = "SELECT * FROM review_complete r LEFT JOIN business_complete b on r.business_id = b.business_id"
# !psql -h localhost -d yelp -c "explain analyze $result_2c_str"
# Out:
#                                                           QUERY PLAN
# -------------------------------------------------------------------------------------------------------------------------------
#  Hash Left Join  (cost=13.82..778.08 rows=15792 width=704) (actual time=0.086..4.432 rows=7500 loops=1)
#    Hash Cond: (r.business_id = b.business_id)
#    ->  Seq Scan on review_complete r  (cost=0.00..721.92 rows=15792 width=256) (actual time=0.010..2.366 rows=7500 loops=1)
#    ->  Hash  (cost=11.70..11.70 rows=170 width=448) (actual time=0.057..0.059 rows=35 loops=1)
#          Buckets: 1024  Batches: 1  Memory Usage: 32kB
#          ->  Seq Scan on business_complete b  (cost=0.00..11.70 rows=170 width=448) (actual time=0.003..0.018 rows=35 loops=1)
#  Planning Time: 0.676 ms
#  Execution Time: 4.808 ms
# (8 rows)

# %% [markdown]
# Now, let's perform the equivalent left join in Mongo between `review` and `business`. **The output array field should be named as `business_info`**. Feel free to refer to the `$lookup` documentation: https://docs.mongodb.com/manual/reference/operator/aggregation/lookup/.
#
# **Note:** You will provide a single-stage pipeline to `review.aggregate(...)` as your solution. Save your pipeline to `q2c_pipeline`.

# %%
# We first create an index on business_id in the business collection
business.create_index('business_id', unique=True)

q2c_pipeline = [{'$lookup': {'from': 'business', 'localField': 'business_id', 
                             'foreignField': 'business_id', 'as' : 'business_info'}}]

result_2c = list(review.aggregate(q2c_pipeline))[:5]

# %%
# Do not delete/edit this cell
result_2c = list(review.aggregate(q2c_pipeline))[:5]
pickle.dump(result_2c, open("results/result_2c.p", "wb"))

# %%
grader.check("q2c")
# Out:
# q2c results: All test cases passed!

# %% [markdown]
# Run the following cell to examine the query plan for the Mongo query that you just wrote. Again, make a mental note of the execution time that you see (you can find the value corresponding to the key `executionTimeMillis`).

# %%
mydb.command('explain', {'aggregate': 'review', 'pipeline': q2c_pipeline, 'cursor': {}}, verbosity='executionStats')
# Out:
# {'explainVersion': '1',
#  'stages': [{'$cursor': {'queryPlanner': {'namespace': 'yelp.review',
#      'indexFilterSet': False,
#      'parsedQuery': {},
#      'queryHash': '8B3D4AB8',
#      'planCacheKey': 'D542626C',
#      'maxIndexedOrSolutionsReached': False,
#      'maxIndexedAndSolutionsReached': False,
#      'maxScansToExplodeReached': False,
#      'winningPlan': {'stage': 'COLLSCAN', 'direction': 'forward'},
#      'rejectedPlans': []},
#     'executionStats': {'executionSuccess': True,
#      'nReturned': 7500,
#      'executionTimeMillis': 493,
#      'totalKeysExamined': 0,
#      'totalDocsExamined': 7500,
#      'executionStages': {'stage': 'COLLSCAN',
#       'nReturned': 7500,
#       'executionTimeMillisEstimate': 0,
#       'works': 7502,
#       'advanced': 7500,
#       'needTime': 1,
#       'needYield': 0,
#       'saveState': 10,
#       'restoreState': 10,
#       'isEOF': 1,
#       'direction': 'forward',
#       'docsExamined': 7500}}},
#    'nReturned': 7500,
#    'executionTimeMillisEstimate': 7},
#   {'$lookup': {'from': 'business',
#     'as': 'business_info',
#     'localField': 'business_id',
#     'foreignField': 'business_id'},
#    'totalDocsExamined': 7500,
#    'totalKeysExamined': 7500,
#    'collectionScans': 0,
#    'indexesUsed': ['business_id_1'],
#    'nReturned': 7500,
#    'executionTimeMillisEstimate': 493}],
#  'serverInfo': {'host': 'jupyter-yeomjiho',
#   'port': 27017,
#   'version': '5.0.11',
#   'gitVersion': 'd08c3c41c105cde798ca934e3ac3426ac11b57c3'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600},
#  'command': {'aggregate': 'review',
#   'pipeline': [{'$lookup': {'from': 'business',
#      'localField': 'business_id',
#      'foreignField': 'business_id',
#      'as': 'business_info'}}],
#   'cursor': {},
#   '$db': 'yelp'},
#  'ok': 1.0}

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Question 2d
#
# In the last question, you performed equivalent left joins in both Postgres and Mongo, and examined their query plans. Which join was faster? What gives that database system you chose an advantage over the other?
# <!--
# BEGIN QUESTION
# name: q2d
# manual: true
# points: 2
# -->

# %% [markdown]
# The execution time for Postgres took 13.899 ms whereas MongoDB took 839 ms. This shows that Postgres is much faster in joining this is becuase "Lookup" cannot yet do Merge joins or hash joins. It is far more suitable for enumerations where there is a limited range of alternatives.

# %% [markdown]
# <!-- END QUESTION -->
#
#
#
# ## Question 3: Dataframes / Pandas
#
# ### Question 3a
#
# So far, we've talked about NoSQL / document databases like Mongo and relational databases like Postgres. Now, we will explore data transformation with a different data model: dataframes. Dataframes are similar to relations with some differences as we will dive into here. To that end, we will use Pandas which is a Python package that allows you to work with dataframes. Pandas is widely adopted by data scientists for data loading, wrangling, cleaning, and analysis. To start, let us export our MongoDB collections into Pandas using a function called `json_normalize`. We need to truncate
# `business` before we can use it to meet the memory constraints set by Jupyter. The variable `business_trunc` will contain the reference the truncated business collection.

# %%
business_trunc = mydb["business_trunc"]
count = 0
if business_trunc.count_documents({}) != 1000:
    for document in business.find({}):
        count += 1
        business_trunc.insert_one(document)
        if count == 1000:
            break

business_cursor = business_trunc.find({})
review_cursor = mydb["reviews"].find({})
user_cursor = mydb["users"].find({})

# Load the collections into Pandas. 
from pandas import json_normalize
user_df = json_normalize(user_cursor)
review_df = json_normalize(review_cursor)
business_df = json_normalize(business_cursor)

# %% [markdown]
# For the rest of Question 3, please use the 3 dataframes we just created: `user_df`, `review_df`, and `business_df`. Let's take a look at the first 5 rows of `business_df`.

# %%
business_df.head()
# Out:
#                         _id             business_id                     name  \
# 0  6365c56f01bec29b734e4e9c  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom
# 1  6365c56f01bec29b734e4e9d  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX
# 2  6365c56f01bec29b734e4e9e  bvN78flM8NLprQ1a1y5dRg           The Reclaimory
# 3  6365c56f01bec29b734e4e9f  oaepsyvc0J17qwi8cfrOWg              Great Clips
# 4  6365c56f01bec29b734e4ea0  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus
#
#                address         city state postal_code   latitude   longitude  \
# 0         921 Pearl St      Boulder    CO       80302  40.017544 -105.283348
# 1  7000 NE Airport Way     Portland    OR       97218  45.588906 -122.593331
# 2   4720 Hawthorne Ave     Portland    OR       97214  45.511907 -122.613693
# 3   2566 Enterprise Rd  Orange City    FL       32763  28.914482  -81.295979
# 4  1046 Memorial Dr SE      Atlanta    GA       30316  33.747027  -84.353424
#
#    stars  ...  attributes.GoodForDancing  attributes.BestNights  \
# 0    4.0  ...                        NaN                    NaN
# 1    4.0  ...                        NaN                    NaN
# 2    4.5  ...                        NaN                    NaN
# 3    3.0  ...                        NaN                    NaN
# 4    4.0  ...                        NaN                    NaN
#
#   attributes.Music attributes.BYOB attributes.CoatCheck attributes.Smoking  \
# 0              NaN             NaN                  NaN                NaN
# 1              NaN             NaN                  NaN                NaN
# 2              NaN             NaN                  NaN                NaN
# 3              NaN             NaN                  NaN                NaN
# 4              NaN             NaN                  NaN                NaN
#
#   attributes.DriveThru attributes.BYOBCorkage attributes.Corkage  \
# 0                  NaN                    NaN                NaN
# 1                  NaN                    NaN                NaN
# 2                  NaN                    NaN                NaN
# 3                  NaN                    NaN                NaN
# 4                  NaN                    NaN                NaN
#
#   attributes.RestaurantsCounterService
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 58 columns]

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# What do you notice about how the columns of `business_df` are constructed? Compare and contrast this dataframe representation with the document representation we saw with Mongo.
#
# <!--
# BEGIN QUESTION
# name: q3a
# manual: true
# points: 1
# -->

# %% [markdown]
# The dataframe representation makes the data into a matrix format which makes it easier to read the columns and the data by having index for each row. However, document representation arranges data in a dictionary format which makes it harder to read column names and data compared to dataframe representation.

# %% [markdown]
# <!-- END QUESTION -->
#
#
#
# ### Question 3b
#
# In the previous question, we talked about how Mongo and Postgres approach joins. Pandas is also capable of performing joins using the [merge()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) function! For this task, perform a inner join on `business_df` with itself on `stars`. The final dataframe should be saved to a variable called `result_3b` and should only contain 3 columns in this particular order: the name of the first restaurant, the name of the second restaurant, and the number of the stars. The column names can be arbitrary.
#
# **Hint:** Check out [this tutorial](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html) on selecting a subset of the Dataframe. This will be helpful in the rest of Question 3 as well!

# %%
business_df.merge(business_df,how = 'inner',on = 'stars')[['name_x','name_y','stars']]
# Out:
#                      name_x                        name_y  stars
# 0       Oskar Blues Taproom           Oskar Blues Taproom    4.0
# 1       Oskar Blues Taproom       Flying Elephants at PDX    4.0
# 2       Oskar Blues Taproom             Crossfit Terminus    4.0
# 3       Oskar Blues Taproom      Capital City Barber Shop    4.0
# 4       Oskar Blues Taproom  Star Kreations Salon and Spa    4.0
# ...                     ...                           ...    ...
# 153959     White Egret Farm           Bluffs at Town Lake    1.5
# 153960     White Egret Farm                   Taco Cabana    1.5
# 153961     White Egret Farm                         Shaws    1.5
# 153962     White Egret Farm                Steak ’n Shake    1.5
# 153963     White Egret Farm              White Egret Farm    1.5
#
# [153964 rows x 3 columns]

# %%
result_3b = business_df.merge(business_df,how = 'inner',on = 'stars')[['name_x','name_y','stars']]

# %%
# Do not delete/edit this cell
result_3b.columns = ['first', 'second', 'stars']
result_3b.sort_values(['first', 'second', 'stars'])[:50].to_csv('results/result_3b.csv', index=False)

# %%
grader.check("q3b")
# Out:
# q3b results: All test cases passed!

# %% [markdown]
# ### Question 3c
#
# Due to the nested representation of the data, there are a lot of missing fields with NaN values in the `business_df` dataframe as you may have noticed in 3a. Construct a dataframe `missing_value_df` with two columns: `column_name` and `percent_missing`. `percent_missing` should be the percentage of NaN values in the corresponding column in `business_df`.
#
# **Hint:** use Pandas' [isnull()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isnull.html) function followed by sum().

# %%
row = business_df.shape[0]
percent = (business_df.isnull().sum() / row)*100
d = {'column_name' : business_df.columns , 'percent_missing' : percent}
missing_value_df = pd.DataFrame(d)

# %%
# Do not delete/edit this cell
missing_value_df.to_csv('results/result_3c.csv', index=False)

# %%
pd.read_csv('results/result_3c.csv')
# Out:
#                               column_name  percent_missing
# 0                                     _id              0.0
# 1                             business_id              0.0
# 2                                    name              0.0
# 3                                 address              0.0
# 4                                    city              0.0
# 5                                   state              0.0
# 6                             postal_code              0.0
# 7                                latitude              0.0
# 8                               longitude              0.0
# 9                                   stars              0.0
# 10                           review_count              0.0
# 11                                is_open              0.0
# 12                             categories              0.1
# 13     attributes.RestaurantsTableService             89.1
# 14                        attributes.WiFi             64.8
# 15                 attributes.BikeParking             52.2
# 16             attributes.BusinessParking             38.6
# 17  attributes.BusinessAcceptsCreditCards             25.4
# 18     attributes.RestaurantsReservations             72.8
# 19        attributes.WheelchairAccessible             80.0
# 20                      attributes.Caters             75.5
# 21              attributes.OutdoorSeating             71.1
# 22    attributes.RestaurantsGoodForGroups             73.7
# 23                   attributes.HappyHour             90.9
# 24      attributes.BusinessAcceptsBitcoin             90.2
# 25      attributes.RestaurantsPriceRange2             42.2
# 26                    attributes.Ambience             73.8
# 27                       attributes.HasTV             73.9
# 28                     attributes.Alcohol             74.4
# 29                 attributes.GoodForMeal             81.4
# 30                 attributes.DogsAllowed             87.8
# 31          attributes.RestaurantsTakeOut             65.4
# 32                  attributes.NoiseLevel             76.4
# 33           attributes.RestaurantsAttire             75.5
# 34         attributes.RestaurantsDelivery             68.6
# 35                           hours.Monday             24.0
# 36                          hours.Tuesday             19.6
# 37                        hours.Wednesday             18.6
# 38                         hours.Thursday             17.6
# 39                           hours.Friday             18.6
# 40                         hours.Saturday             29.7
# 41                           hours.Sunday             46.5
# 42                 attributes.GoodForKids             64.7
# 43           attributes.ByAppointmentOnly             66.7
# 44                                  hours            100.0
# 45            attributes.AcceptsInsurance             95.0
# 46                             attributes            100.0
# 47           attributes.HairSpecializesIn             99.2
# 48              attributes.GoodForDancing             97.5
# 49                  attributes.BestNights             96.5
# 50                       attributes.Music             95.4
# 51                        attributes.BYOB             98.3
# 52                   attributes.CoatCheck             97.0
# 53                     attributes.Smoking             97.1
# 54                   attributes.DriveThru             96.8
# 55                 attributes.BYOBCorkage             97.9
# 56                     attributes.Corkage             98.1
# 57   attributes.RestaurantsCounterService             99.9

# %%
grader.check("q3c")
# Out:
# q3c results: All test cases passed!

# %% [markdown]
# ### Question 3d
#
# Plot a histogram distribution of the percentage of NaN values across all columns (via Pandas [hist()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html) function). Don't worry about putting titles / making it look nice - we won't be grading the plot.

# %%
# PLOT HERE
missing_value_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'percent_missing'}>]], dtype=object)

# %% [markdown]
# Examine the histogram that you just plotted. How many columns are 90%+ NaN? Input your answer into `result_q3d` as an integer (e.g. if your answer is 6, then `result_q3d = 6`)
#
# <!--
# BEGIN QUESTION
# name: q3d
# points: 1
# -->

# %%
result_q3d = 16

# %%
grader.check("q3d")
# Out:
# q3d results: All test cases passed!

# %% [markdown]
# ### Question 3e
#
# Let us now alter `business_df` to exclude the columns with more than 80%+ null values (keep columns with 80% null values or less). This likely means the corresponding attributes are not an important factor for most businesses so we can get rid of them in our `business_df`. Create a new dataframe called `important_attribute_business_df` which only contains these columns.
#
# **Hint:** check out [this section](https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html#how-do-i-select-specific-rows-and-columns-from-a-dataframe) from the tutorial linked in Q3b.

# %%
ucn = missing_value_df[missing_value_df['percent_missing'] <= 80]['column_name'].unique()
len(ucn)
# Out:
# 39

# %%
important_attribute_business_df = business_df.loc[:,ucn]

# %%
# Do not delete/edit this cell
important_attribute_business_df.to_csv('results/result_3e.csv', index=False)

# %%
pd.read_csv('results/result_3e.csv')
# Out:
#                           _id             business_id  \
# 0    6365c56f01bec29b734e4e9c  6iYb2HFDywm3zjuRg0shjw
# 1    6365c56f01bec29b734e4e9d  tCbdrRPZA0oiIYSmHG3J0w
# 2    6365c56f01bec29b734e4e9e  bvN78flM8NLprQ1a1y5dRg
# 3    6365c56f01bec29b734e4e9f  oaepsyvc0J17qwi8cfrOWg
# 4    6365c56f01bec29b734e4ea0  PE9uqAjdw0E4-8mjGl3wVA
# ..                        ...                     ...
# 995  6365c57001bec29b734e527f  HQ1fwOWzYK5zSxTGSwSvmw
# 996  6365c57001bec29b734e5280  LOiS95cRQbPrbRZ2-fMXbg
# 997  6365c57001bec29b734e5281  9irir2PpYr_yY5lNWYqUWA
# 998  6365c57001bec29b734e5282  2cG2YiR8Tg-YCJJfaHJtYw
# 999  6365c57001bec29b734e5283  OhpdMOXon32xdJ0-OeL5-Q
#
#                            name              address         city state  \
# 0           Oskar Blues Taproom         921 Pearl St      Boulder    CO
# 1       Flying Elephants at PDX  7000 NE Airport Way     Portland    OR
# 2                The Reclaimory   4720 Hawthorne Ave     Portland    OR
# 3                   Great Clips   2566 Enterprise Rd  Orange City    FL
# 4             Crossfit Terminus  1046 Memorial Dr SE      Atlanta    GA
# ..                          ...                  ...          ...   ...
# 995                     Dunkin'      99 Cambridge St  Charlestown    MA
# 996           Shane's Rib Shack     1221 Caroline St      Atlanta    GA
# 997        Subaru North Orlando    4113 S Orlando Dr      Sanford    FL
# 998  Elements Massage - Medford           40 High St      Medford    MA
# 999               Pirate's Cove   7417 NE Sandy Blvd     Portland    OR
#
#     postal_code   latitude   longitude  stars  ...  \
# 0         80302  40.017544 -105.283348    4.0  ...
# 1         97218  45.588906 -122.593331    4.0  ...
# 2         97214  45.511907 -122.613693    4.5  ...
# 3         32763  28.914482  -81.295979    3.0  ...
# 4         30316  33.747027  -84.353424    4.0  ...
# ..          ...        ...         ...    ...  ...
# 995       02129  42.382539  -71.079236    2.0  ...
# 996       30307  33.758258  -84.348474    3.0  ...
# 997       32773  28.749161  -81.291087    4.0  ...
# 998       02155  42.418388  -71.111116    4.0  ...
# 999       97213  45.549482 -122.586522    3.5  ...
#
#      attributes.RestaurantsDelivery  hours.Monday hours.Tuesday  \
# 0                              None     11:0-23:0     11:0-23:0
# 1                             False      5:0-18:0      5:0-17:0
# 2                               NaN           NaN           NaN
# 3                               NaN           NaN           NaN
# 4                               NaN     16:0-19:0     16:0-19:0
# ..                              ...           ...           ...
# 995                            True      5:0-23:0      5:0-23:0
# 996                            True     11:0-21:0     11:0-21:0
# 997                             NaN     10:0-18:0     8:30-20:0
# 998                             NaN      9:0-21:0      9:0-21:0
# 999                             NaN     14:0-2:30     14:0-2:30
#
#     hours.Wednesday hours.Thursday hours.Friday hours.Saturday hours.Sunday  \
# 0         11:0-23:0      11:0-23:0    11:0-23:0      11:0-23:0    11:0-23:0
# 1          5:0-18:0       5:0-18:0     5:0-18:0       5:0-18:0     5:0-18:0
# 2               NaN      11:0-18:0    11:0-18:0      11:0-18:0    11:0-18:0
# 3               NaN            NaN          NaN            NaN          NaN
# 4         16:0-19:0      16:0-19:0    16:0-19:0       9:0-11:0          NaN
# ..              ...            ...          ...            ...          ...
# 995        5:0-23:0       5:0-23:0     5:0-23:0       5:0-23:0     5:0-23:0
# 996       11:0-21:0      11:0-21:0    11:0-21:0      11:0-21:0    11:0-21:0
# 997       8:30-20:0      8:30-20:0    8:30-20:0      8:30-18:0          NaN
# 998        9:0-21:0       9:0-21:0     9:0-21:0       9:0-21:0     9:0-21:0
# 999       14:0-2:30      14:0-2:30    14:0-2:30      14:0-2:30    14:0-2:30
#
#     attributes.GoodForKids attributes.ByAppointmentOnly
# 0                      NaN                          NaN
# 1                     True                        False
# 2                      NaN                        False
# 3                     True                        False
# 4                    False                          NaN
# ..                     ...                          ...
# 995                   True                        False
# 996                   True                          NaN
# 997                    NaN                        False
# 998                    NaN                        False
# 999                    NaN                          NaN
#
# [1000 rows x 39 columns]

# %%
grader.check("q3e")
# Out:
# q3e results: All test cases passed!

# %% [markdown]
# ### Question 3f
#
# At this point, you have had experience with manipulating data on Mongo, Postgres, and Pandas. In this question, we will provide 3 scenarios and using the lessons you've learned so far, please specify which of the three (Mongo, Postgres, or Pandas) would work best for this specific use case.
#
# 1. You are doing a data journalism piece on college sports. You collect a list of colleges and for each collegiate sport program within that college, you find the budget assigned for that program. You have a choice between the following:
#
#     A) Representing this data in JSON (e.g.
#     ```
#     {
#         "UC Berkeley": {
#             "football": "10000000",
#             "wrestling": "344582",
#             ...}
#     }
#     ```
#     ) and importing into Mongo.
#
#     B) Representing this data as a schema in Postgres where the columns are the names of the sports.
#
#     C) Representing this data as a dataframe in Pandas where the columns are the names of the sports.
#
# You would like to find the aggregate of budgets across different sports (average, sum, median, mode). What would be the best option for storing this data?
#
# **NOTE**: Your answer should look like `q3fi_str = ['A']` or `q3fi_str = ['B']` or `q3fi_str = ['C']`.
#
# <!--
# BEGIN QUESTION
# name: q3fi
# points: 1
# -->

# %%
q3fi_str = ['C']

# %%
grader.check("q3fi")
# Out:
# q3fi results: All test cases passed!

# %% [markdown]
# 2. You would now like to investigate what effect does budget have on student-athlete scholarships. After doing some research, you find a dataset that contains a list of every single athlete at every single college and their sport and scholarship levels (this is a massive 10GB+ dataset with millions of rows). You find another dataset that contains a list of colleges, their sports programs, and the program budget. This is another massive dataset with hundreds of thousands of rows. You would like to perform an inner join between the two datasets on school and program so you can view each student-athlete's scholarship with their sport's budget. You have a choice between the following:
#
#     A) Representing each dataset in JSON (e.g.
#     ```
#     {"athletes": [
#         {"Chase Garbers": {
#             "school": "UC Berkeley",
#             "scholarship": "full",
#             "sport": "football",
#             ...
#             }
#         },
#         ...
#     ]}
#     ```
#     and
#     ```
#     {"schools": [
#         {"UC Berkeley": {
#             "football": {
#                 "budget": "10000000"
#              },
#              ...
#              }
#         },
#         ...
#      ]}
#      ```
#     ), importing into Mongo, and doing a join there.
#
#     B) Representing this data as 2 schemas in Postgres where the columns for the first schema are
#     [`student_name`, `school`, `sport`, `scholarship`] and for the second [`school`, `sport`, `budget`].
#
#     C) Representing this data as 2 dataframes in Pandas with the same columns as Postgres.
#
# What would be the best option for storing this data?
#
# **NOTE**: Your answer should look like `q3fii_str = ['A']` or `q3fii_str = ['B']` or `q3fii_str = ['C']` or `q3fii_str = ['D']`
#
# <!--
# BEGIN QUESTION
# name: q3fii
# points: 1
# -->

# %%
q3fii_str = ['B']

# %%
grader.check("q3fii")
# Out:
# q3fii results: All test cases passed!

# %% [markdown]
# 3. Finally, you are ready to start writing your article! You decide to focus on just the data from UC Berkeley. You have access to a dataset of just UC Berkeley athletes along with their sports and scholarship levels. The scholarship level data was improperly cleaned: some scholarships are recorded as strings "full", "half", or "none" and some are recorded as integer percentages 0-100. You would like to provide this data to your readers in a format that is susceptible to easy visualizations: e.g. graphs that show how many athletes have a full vs. half vs. no scholarship, which sports have the highest percentages of athletes with full scholarships etc. What is the best way to store this data for this purpose?
#
#     A) Represent the dataset in JSON e.g.
#     ```
#     {"athletes": [
#         {
#            "Chase Garbers": {
#              "scholarship": "full",
#              "sport": "football"
#            }
#         },
#         {
#             "Danielle Vosk": {
#               "scholarship": 25,
#               "sport": "basketball"
#             }
#         },
#         ...
#         ]
#     }
#     ```
#     B) Represent this data as a schema in Postgres where the columns are [`student_name`, `sport`, `scholarship`]
#
#     C) Represent this data as a dataframe in Pandas with the same columns as Postgres.
#
# **NOTE**: Your answer should look like `q3fiii_str = ['A']` or `q3fiii_str = ['B']` or `q3fiii_str = ['C']` or `q3fiii_str = ['D']`
#
# <!--
# BEGIN QUESTION
# name: q3fiii
# points: 1
# -->

# %%
q3fiii_str = ['A']

# %%
grader.check("q3fiii")
# Out:
# q3fiii results: All test cases passed!

# %% [markdown]
# ## Question 4: Messy JSON
#
# Many of the queries you've seen or written thus far were relatively reliable: aggregating and collecting over fields
# that you know exist for sure. But the nature of Mongo documents is that they are inherently flexible and semi-structured. Not every document will share every single field! In this question, we will explore how Mongo handles these use cases using the `business` collection.
#
# ### Question 4a
#
# Imagine you are in charge of managing your family reunion. You would like to book a private room at a restaurant.
# However, you would also like to optimize for chaos. You notice that there is an attribute called `RestaurantsGoodForGroups`. You would like to write a query that returns all restaurants that **do not** have the `RestaurantsGoodForGroups` attribute so that the trajectory of the reunion is determined by fate (hint: search up the `$exists` keyword). Your output for the autograder will be the integer number of restaurants that do not have the `RestaurantsGoodForGroups` attribute stored in `q4a_str`.
#
# **Note:** You would like this list to consist solely of restaurants. This means that the business must have `Restaurants` in the `categories` field. You may perform a similar text search as question 1d. **This holds true for the rest of the Question 4 as well!**

# %%
# rest = list(business.find({'$text': {'$search': 'Restaurants'}}))
# temp = []
# count = 0
# for r in rest:
#     if (r['attributes'] is None) or ("RestaurantsGoodForGroups" not in r['attributes'].keys())  :
#         temp.append(r)
#         count = count + 1

# %%
# The following text index may be useful!
if 'categories_text' not in business.index_information():
    business.create_index([('categories', TEXT)])



q4a_str = len(list(business.find({'$text': {'$search': 'Restaurants'},'attributes.RestaurantsGoodForGroups': {'$exists' : False} })))

# %% [markdown]
# How many restaurants do not have the `RestaurantsGoodForGroups` attribute? You may either enter input this is a function with respect to your query or hardcode in either the String or the numeric version of the answer you computed.

# %%
# Do not delete/edit this cell
pickle.dump(q4a_str, open("results/result_4a.p", "wb"))

# %%
grader.check("q4a")
# Out:
# q4a results: All test cases passed!

# %%
pickle.load(open("results/result_4a.p", "rb"))
# Out:
# 8237

# %% [markdown]
# ### Question 4b
#
# Your relatives inform you that they would like to be at the restaurant when it opens to beat the crowds. Furthermore, after sending
# a when2meet, most of your relatives would prefer for the meal to be on a Friday and the start time of the meal to be
# between 5-6:59PM (17:00-18:59). Find the number of restaurants that open on Fridays between 17:00-18:59 (you only have to consider the opening time!) and store this in a variable labeled `q4b_str`. As a reminder, in order for a business to be a restaurant, it must have `Restaurant` in its categories. Be aware that `hours` can either be an array or `None`!
#
# **Hint**: Set up an aggregation pipeline using the `$set` and `$match` stage operators. You may also want to use the `$split` operator to parse out the Friday hours. Note that using dot notation for array indexing in aggregation pipelines may not work as expected, so we recommend using `$arrayElemAt` operator.

# %%
#1) meal on friday, opening time 17-18:59
#2) output : number of restaurants 
#3) category : Restarurant, hours= array or None

# %%
if 'categories_text' not in business.index_information():
    business.create_index([('categories', TEXT)])

te = list(business.aggregate([
    {'$match': {'$text': {'$search': 'Restaurant'}}},
    {'$project' : { 'openTime' : {'$split': ['$hours.Friday','-']}}},
    {'$set' : {'open_time' :{'$arrayElemAt': ['$openTime', 0]}}},
    {'$set' : { 'ot' : {'$split': ['$open_time',':']}}},
    {'$set' : {'open_hours' :{'$arrayElemAt': ['$ot', 0]}}},
    {'$match': { 'open_hours': { '$gte': '17', '$lt': '19' } }},
    ]))

q4b_str = len(te)

# %%
# Do not delete/edit this cell
pickle.dump(q4b_str, open("results/result_4b.p", "wb"))

# %%
grader.check("q4b")
# Out:
# q4b results: All test cases passed!

# %% [markdown]
# ### Question 4c
#
# Some members of your family are vegetarian so you would like to only eat at restaurants with the Vegetarian category.
# However, the `categories` are stored as a single string! You would like to make it easy to access Vegetarian as a separate field. Write a query that does the following: for every category in `categories`, add a new document that contains the `ObjectId` for the previous document (labeled `_id`), the name of the business (labeled `name`), and the category (labeled `category`).
#
# For example, a document
# ```
# {
#     "_id": ObjectId('606ffb0123cf2e5079dbd91f'),
#     "name": "Wendy's",
#      ...,
#      categories" : "Salad, Vegetarian"
# }
# ```
# would become
# ```
# {
#     "_id": ObjectId('606ffb0123cf2e5079dbd91f'),
#     "name": "Wendy's",
#     “category”: "Salad"
# }
# ```
# and
# ```
# {
#     "_id": ObjectId('606ffb0123cf2e5079dbd91f'),
#     "name": "Wendy's",
#     “category”: "Vegetarian"
# }
# ```
#
# Finally, to ensure your output is consistent with the autograder, sort in ascending order by `name` and break ties on `category`. Save your pipeline to a variable called `q4c_pipeline`.
#
# **Hint:** the `$unwind` operator may be helpful here. Watch out to make sure you don't have any unnecessary space in the `category` field.

# %%
# $unwind 사용
# $sort : {'name' : 1, 'category' : 1} 
# category 에 이상한 space있는지 잘 확인하기 
list(business.aggregate([
    {'$match': {'$text': {'$search': 'Restaurants'}}},
    {'$set' : { 'cat' : {'$split': ['$categories',', ']}}},
    {'$unwind' : '$cat'},
    {'$project' : {'_id':'$_id','name':'$name','category': '$cat'}}, 
    {'$sort' : {'name' : 1, 'category' : 1}}  
]))
# Out:
# [{'_id': ObjectId('6365c57801bec29b734e84b3'),
#   'name': " Gruby's New York Deli",
#   'category': 'Caterers'},
#  {'_id': ObjectId('6365c57801bec29b734e84b3'),
#   'name': " Gruby's New York Deli",
#   'category': 'Delis'},
#  {'_id': ObjectId('6365c57801bec29b734e84b3'),
#   'name': " Gruby's New York Deli",
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c57801bec29b734e84b3'),
#   'name': " Gruby's New York Deli",
#   'category': 'Kosher'},
#  {'_id': ObjectId('6365c57801bec29b734e84b3'),
#   'name': " Gruby's New York Deli",
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57801bec29b734e84b3'),
#   'name': " Gruby's New York Deli",
#   'category': 'Salad'},
#  {'_id': ObjectId('6365c57801bec29b734e84b3'),
#   'name': " Gruby's New York Deli",
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5a001bec29b734f7dc2'),
#   'name': '# 19',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5a001bec29b734f7dc2'),
#   'name': '# 19',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a001bec29b734f7dc2'),
#   'name': '# 19',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5a401bec29b734f98a3'),
#   'name': '#1 Express China Lee',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c5a401bec29b734f98a3'),
#   'name': '#1 Express China Lee',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57601bec29b734e7978'),
#   'name': '#FROYO Premium Frozen Yogurt',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c57601bec29b734e7978'),
#   'name': '#FROYO Premium Frozen Yogurt',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57601bec29b734e7978'),
#   'name': '#FROYO Premium Frozen Yogurt',
#   'category': 'Ice Cream & Frozen Yogurt'},
#  {'_id': ObjectId('6365c57601bec29b734e7978'),
#   'name': '#FROYO Premium Frozen Yogurt',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bb01bec29b73502960'),
#   'name': '& Juice',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5bb01bec29b73502960'),
#   'name': '& Juice',
#   'category': 'Juice Bars & Smoothies'},
#  {'_id': ObjectId('6365c5bb01bec29b73502960'),
#   'name': '& Juice',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bb01bec29b73502960'),
#   'name': '& Juice',
#   'category': 'Vegan'},
#  {'_id': ObjectId('6365c5bb01bec29b73502960'),
#   'name': '& Juice',
#   'category': 'Vegetarian'},
#  {'_id': ObjectId('6365c57f01bec29b734eb163'),
#   'name': '& Juice Co.',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57f01bec29b734eb163'),
#   'name': '& Juice Co.',
#   'category': 'Gluten-Free'},
#  {'_id': ObjectId('6365c57f01bec29b734eb163'),
#   'name': '& Juice Co.',
#   'category': 'Juice Bars & Smoothies'},
#  {'_id': ObjectId('6365c57f01bec29b734eb163'),
#   'name': '& Juice Co.',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57f01bec29b734eb163'),
#   'name': '& Juice Co.',
#   'category': 'Vegan'},
#  {'_id': ObjectId('6365c57f01bec29b734eb163'),
#   'name': '& Juice Co.',
#   'category': 'Vegetarian'},
#  {'_id': ObjectId('6365c57501bec29b734e7216'),
#   'name': '&pizza - Harvard Square',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c57501bec29b734e7216'),
#   'name': '&pizza - Harvard Square',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57501bec29b734e7216'),
#   'name': '&pizza - Harvard Square',
#   'category': 'Vegan'},
#  {'_id': ObjectId('6365c57501bec29b734e7216'),
#   'name': '&pizza - Harvard Square',
#   'category': 'Vegetarian'},
#  {'_id': ObjectId('6365c5d201bec29b7350be87'),
#   'name': "'63 South",
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5d201bec29b7350be87'),
#   'name': "'63 South",
#   'category': 'Delis'},
#  {'_id': ObjectId('6365c5d201bec29b7350be87'),
#   'name': "'63 South",
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5d201bec29b7350be87'),
#   'name': "'63 South",
#   'category': 'Salad'},
#  {'_id': ObjectId('6365c5d201bec29b7350be87'),
#   'name': "'63 South",
#   'category': 'Vegan'},
#  {'_id': ObjectId('6365c5c501bec29b73506acd'),
#   'name': "'O' Yummy Cuisine",
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c5c501bec29b73506acd'),
#   'name': "'O' Yummy Cuisine",
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c501bec29b73506acd'),
#   'name': "'O' Yummy Cuisine",
#   'category': 'Sushi Bars'},
#  {'_id': ObjectId('6365c5c901bec29b735085fb'),
#   'name': "'ONO raw bar",
#   'category': 'Japanese'},
#  {'_id': ObjectId('6365c5c901bec29b735085fb'),
#   'name': "'ONO raw bar",
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c901bec29b735085fb'),
#   'name': "'ONO raw bar",
#   'category': 'Seafood'},
#  {'_id': ObjectId('6365c5c901bec29b735085fb'),
#   'name': "'ONO raw bar",
#   'category': 'Sushi Bars'},
#  {'_id': ObjectId('6365c57d01bec29b734ea054'),
#   'name': "'Ohana",
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c57d01bec29b734ea054'),
#   'name': "'Ohana",
#   'category': 'Hawaiian'},
#  {'_id': ObjectId('6365c57d01bec29b734ea054'),
#   'name': "'Ohana",
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Arts & Entertainment'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Beer'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Music Venues'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Tapas Bars'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Tapas/Small Plates'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Wine & Spirits'},
#  {'_id': ObjectId('6365c5a701bec29b734fb035'),
#   'name': '/pôr/ wine house',
#   'category': 'Wine Bars'},
#  {'_id': ObjectId('6365c5c101bec29b73504c8e'),
#   'name': '051 Subs',
#   'category': 'Cheesesteaks'},
#  {'_id': ObjectId('6365c5c101bec29b73504c8e'),
#   'name': '051 Subs',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c101bec29b73504c8e'),
#   'name': '051 Subs',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c59e01bec29b734f7367'),
#   'name': '0755 Lounge',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c59e01bec29b734f7367'),
#   'name': '0755 Lounge',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c59e01bec29b734f7367'),
#   'name': '0755 Lounge',
#   'category': 'Lounges'},
#  {'_id': ObjectId('6365c59e01bec29b734f7367'),
#   'name': '0755 Lounge',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c59e01bec29b734f7367'),
#   'name': '0755 Lounge',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a101bec29b734f898f'),
#   'name': '081 Italian Restaurant & Take Out',
#   'category': 'Caterers'},
#  {'_id': ObjectId('6365c5a101bec29b734f898f'),
#   'name': '081 Italian Restaurant & Take Out',
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c5a101bec29b734f898f'),
#   'name': '081 Italian Restaurant & Take Out',
#   'category': 'Italian'},
#  {'_id': ObjectId('6365c5a101bec29b734f898f'),
#   'name': '081 Italian Restaurant & Take Out',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a101bec29b734f898f'),
#   'name': '081 Italian Restaurant & Take Out',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c56f01bec29b734e50cf'),
#   'name': '081 Wood Fired Pizza',
#   'category': 'Chicken Wings'},
#  {'_id': ObjectId('6365c56f01bec29b734e50cf'),
#   'name': '081 Wood Fired Pizza',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c56f01bec29b734e50cf'),
#   'name': '081 Wood Fired Pizza',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c56f01bec29b734e50cf'),
#   'name': '081 Wood Fired Pizza',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c59001bec29b734f1f00'),
#   'name': '1/2 Roll',
#   'category': 'Japanese'},
#  {'_id': ObjectId('6365c59001bec29b734f1f00'),
#   'name': '1/2 Roll',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59001bec29b734f1f00'),
#   'name': '1/2 Roll',
#   'category': 'Sushi Bars'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac46'),
#   'name': '10 Barrel Brewing Portland',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac46'),
#   'name': '10 Barrel Brewing Portland',
#   'category': 'Beer Gardens'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac46'),
#   'name': '10 Barrel Brewing Portland',
#   'category': 'Breweries'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac46'),
#   'name': '10 Barrel Brewing Portland',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac46'),
#   'name': '10 Barrel Brewing Portland',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac46'),
#   'name': '10 Barrel Brewing Portland',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac46'),
#   'name': '10 Barrel Brewing Portland',
#   'category': 'Pubs'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac46'),
#   'name': '10 Barrel Brewing Portland',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5aa01bec29b734fbe73'),
#   'name': '10 Degrees South',
#   'category': 'African'},
#  {'_id': ObjectId('6365c5aa01bec29b734fbe73'),
#   'name': '10 Degrees South',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58401bec29b734ece70'),
#   'name': '10 HIGH Club',
#   'category': 'Arts & Entertainment'},
#  {'_id': ObjectId('6365c58401bec29b734ece70'),
#   'name': '10 HIGH Club',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c58401bec29b734ece70'),
#   'name': '10 HIGH Club',
#   'category': 'Burgers'},
#  {'_id': ObjectId('6365c58401bec29b734ece70'),
#   'name': '10 HIGH Club',
#   'category': 'Karaoke'},
#  {'_id': ObjectId('6365c58401bec29b734ece70'),
#   'name': '10 HIGH Club',
#   'category': 'Music Venues'},
#  {'_id': ObjectId('6365c58401bec29b734ece70'),
#   'name': '10 HIGH Club',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c58401bec29b734ece70'),
#   'name': '10 HIGH Club',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58401bec29b734ece70'),
#   'name': '10 HIGH Club',
#   'category': 'Tapas Bars'},
#  {'_id': ObjectId('6365c59601bec29b734f449c'),
#   'name': '100 Montaditos',
#   'category': 'Ethnic Food'},
#  {'_id': ObjectId('6365c59601bec29b734f449c'),
#   'name': '100 Montaditos',
#   'category': 'Fast Food'},
#  {'_id': ObjectId('6365c59601bec29b734f449c'),
#   'name': '100 Montaditos',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59601bec29b734f449c'),
#   'name': '100 Montaditos',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59601bec29b734f449c'),
#   'name': '100 Montaditos',
#   'category': 'Specialty Food'},
#  {'_id': ObjectId('6365c59201bec29b734f2a20'),
#   'name': '100 Pizzitas',
#   'category': 'Mediterranean'},
#  {'_id': ObjectId('6365c59201bec29b734f2a20'),
#   'name': '100 Pizzitas',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c59201bec29b734f2a20'),
#   'name': '100 Pizzitas',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59201bec29b734f2a20'),
#   'name': '100 Pizzitas',
#   'category': 'Spanish'},
#  {'_id': ObjectId('6365c59101bec29b734f26a3'),
#   'name': '100% Delicias',
#   'category': 'Caribbean'},
#  {'_id': ObjectId('6365c59101bec29b734f26a3'),
#   'name': '100% Delicias',
#   'category': 'Dominican'},
#  {'_id': ObjectId('6365c59101bec29b734f26a3'),
#   'name': '100% Delicias',
#   'category': 'Latin American'},
#  {'_id': ObjectId('6365c59101bec29b734f26a3'),
#   'name': '100% Delicias',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57101bec29b734e5b49'),
#   'name': '100% Delicias Express',
#   'category': 'Caribbean'},
#  {'_id': ObjectId('6365c57101bec29b734e5b49'),
#   'name': '100% Delicias Express',
#   'category': 'Dominican'},
#  {'_id': ObjectId('6365c57101bec29b734e5b49'),
#   'name': '100% Delicias Express',
#   'category': 'Empanadas'},
#  {'_id': ObjectId('6365c57101bec29b734e5b49'),
#   'name': '100% Delicias Express',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57101bec29b734e5b49'),
#   'name': '100% Delicias Express',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58b01bec29b734efa4b'),
#   'name': '100% Mexicano',
#   'category': 'Mexican'},
#  {'_id': ObjectId('6365c58b01bec29b734efa4b'),
#   'name': '100% Mexicano',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58f01bec29b734f159c'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Fast Food'},
#  {'_id': ObjectId('6365c59201bec29b734f2d0f'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Italian'},
#  {'_id': ObjectId('6365c5b501bec29b73500304'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c57501bec29b734e723d'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c57001bec29b734e52b7'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c59201bec29b734f2d0f'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c58f01bec29b734f159c'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c5b501bec29b73500304'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57501bec29b734e723d'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57001bec29b734e52b7'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59201bec29b734f2d0f'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58f01bec29b734f159c'),
#   'name': '1000 Degrees Neapolitan Pizzeria',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58b01bec29b734efd12'),
#   'name': '1000 Degrees Pizza Salad Wings',
#   'category': 'Chicken Wings'},
#  {'_id': ObjectId('6365c58b01bec29b734efd12'),
#   'name': '1000 Degrees Pizza Salad Wings',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c58b01bec29b734efd12'),
#   'name': '1000 Degrees Pizza Salad Wings',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58b01bec29b734efd12'),
#   'name': '1000 Degrees Pizza Salad Wings',
#   'category': 'Salad'},
#  {'_id': ObjectId('6365c5c101bec29b7350506f'),
#   'name': '101 Bagel Cafe',
#   'category': 'Bagels'},
#  {'_id': ObjectId('6365c5c101bec29b7350506f'),
#   'name': '101 Bagel Cafe',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c5c101bec29b7350506f'),
#   'name': '101 Bagel Cafe',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c5c101bec29b7350506f'),
#   'name': '101 Bagel Cafe',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5c101bec29b7350506f'),
#   'name': '101 Bagel Cafe',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c101bec29b7350506f'),
#   'name': '101 Bagel Cafe',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac81'),
#   'name': '101 Beer Kitchen',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c59601bec29b734f475f'),
#   'name': '101 Beer Kitchen',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c59b01bec29b734f638a'),
#   'name': '101 Beer Kitchen',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c59601bec29b734f475f'),
#   'name': '101 Beer Kitchen',
#   'category': 'Beer'},
#  {'_id': ObjectId('6365c59b01bec29b734f638a'),
#   'name': '101 Beer Kitchen',
#   'category': 'Beer'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac81'),
#   'name': '101 Beer Kitchen',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c59601bec29b734f475f'),
#   'name': '101 Beer Kitchen',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c59b01bec29b734f638a'),
#   'name': '101 Beer Kitchen',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c59b01bec29b734f638a'),
#   'name': '101 Beer Kitchen',
#   'category': 'Comfort Food'},
#  {'_id': ObjectId('6365c59601bec29b734f475f'),
#   'name': '101 Beer Kitchen',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59b01bec29b734f638a'),
#   'name': '101 Beer Kitchen',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac81'),
#   'name': '101 Beer Kitchen',
#   'category': 'Gastropubs'},
#  {'_id': ObjectId('6365c59601bec29b734f475f'),
#   'name': '101 Beer Kitchen',
#   'category': 'Gastropubs'},
#  {'_id': ObjectId('6365c59b01bec29b734f638a'),
#   'name': '101 Beer Kitchen',
#   'category': 'Gastropubs'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac81'),
#   'name': '101 Beer Kitchen',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59601bec29b734f475f'),
#   'name': '101 Beer Kitchen',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59b01bec29b734f638a'),
#   'name': '101 Beer Kitchen',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5cf01bec29b7350ac81'),
#   'name': '101 Beer Kitchen',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c59601bec29b734f475f'),
#   'name': '101 Beer Kitchen',
#   'category': 'Wine & Spirits'},
#  {'_id': ObjectId('6365c59b01bec29b734f638a'),
#   'name': '101 Beer Kitchen',
#   'category': 'Wine & Spirits'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Bubble Tea'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Korean'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59501bec29b734f3bd0'),
#   'name': '101 By Teahaus',
#   'category': 'Taiwanese'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f15'),
#   'name': '101 Steak',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f15'),
#   'name': '101 Steak',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f15'),
#   'name': '101 Steak',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f15'),
#   'name': '101 Steak',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f15'),
#   'name': '101 Steak',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f15'),
#   'name': '101 Steak',
#   'category': 'Seafood'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f15'),
#   'name': '101 Steak',
#   'category': 'Steakhouses'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f15'),
#   'name': '101 Steak',
#   'category': 'Wine Bars'},
#  {'_id': ObjectId('6365c58101bec29b734ebe10'),
#   'name': '1029 Coffee',
#   'category': 'Beer'},
#  {'_id': ObjectId('6365c58101bec29b734ebe10'),
#   'name': '1029 Coffee',
#   'category': 'Cafes'},
#  {'_id': ObjectId('6365c58101bec29b734ebe10'),
#   'name': '1029 Coffee',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c58101bec29b734ebe10'),
#   'name': '1029 Coffee',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c58101bec29b734ebe10'),
#   'name': '1029 Coffee',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58101bec29b734ebe10'),
#   'name': '1029 Coffee',
#   'category': 'Wine & Spirits'},
#  {'_id': ObjectId('6365c58001bec29b734eb4cf'),
#   'name': '103 West',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c58001bec29b734eb4cf'),
#   'name': '103 West',
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c58001bec29b734eb4cf'),
#   'name': '103 West',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58001bec29b734eb4cf'),
#   'name': '103 West',
#   'category': 'Venues & Event Spaces'},
#  {'_id': ObjectId('6365c57101bec29b734e5afb'),
#   'name': '1048 Bar and Grill',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c57101bec29b734e5afb'),
#   'name': '1048 Bar and Grill',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c57101bec29b734e5afb'),
#   'name': '1048 Bar and Grill',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c57101bec29b734e5afb'),
#   'name': '1048 Bar and Grill',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c57101bec29b734e5afb'),
#   'name': '1048 Bar and Grill',
#   'category': 'Pubs'},
#  {'_id': ObjectId('6365c57101bec29b734e5afb'),
#   'name': '1048 Bar and Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58e01bec29b734f12f1'),
#   'name': '108 Bar N Grill',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c58e01bec29b734f12f1'),
#   'name': '108 Bar N Grill',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c58e01bec29b734f12f1'),
#   'name': '108 Bar N Grill',
#   'category': 'Bubble Tea'},
#  {'_id': ObjectId('6365c58e01bec29b734f12f1'),
#   'name': '108 Bar N Grill',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c58e01bec29b734f12f1'),
#   'name': '108 Bar N Grill',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c58e01bec29b734f12f1'),
#   'name': '108 Bar N Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58e01bec29b734f12f1'),
#   'name': '108 Bar N Grill',
#   'category': 'Sports Bars'},
#  {'_id': ObjectId('6365c5bf01bec29b73503f6c'),
#   'name': '10th & Piedmont',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c5bf01bec29b73503f6c'),
#   'name': '10th & Piedmont',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5bf01bec29b73503f6c'),
#   'name': '10th & Piedmont',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c5bf01bec29b73503f6c'),
#   'name': '10th & Piedmont',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bf01bec29b73503f6c'),
#   'name': '10th & Piedmont',
#   'category': 'Seafood'},
#  {'_id': ObjectId('6365c5bf01bec29b73503f6c'),
#   'name': '10th & Piedmont',
#   'category': 'Southern'},
#  {'_id': ObjectId('6365c5ad01bec29b734fd350'),
#   'name': '10th Street Produce and Deli',
#   'category': 'Delis'},
#  {'_id': ObjectId('6365c5ad01bec29b734fd350'),
#   'name': '10th Street Produce and Deli',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5ad01bec29b734fd350'),
#   'name': '10th Street Produce and Deli',
#   'category': 'Fruits & Veggies'},
#  {'_id': ObjectId('6365c5ad01bec29b734fd350'),
#   'name': '10th Street Produce and Deli',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5ad01bec29b734fd350'),
#   'name': '10th Street Produce and Deli',
#   'category': 'Specialty Food'},
#  {'_id': ObjectId('6365c5b101bec29b734fed13'),
#   'name': '110 Grill',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c59801bec29b734f4f10'),
#   'name': '110 Grill',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c59101bec29b734f274e'),
#   'name': '110 Grill',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c5b101bec29b734fed04'),
#   'name': '110 Grill',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c57e01bec29b734ea97d'),
#   'name': '110 Grill',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c5b101bec29b734fed13'),
#   'name': '110 Grill',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c59801bec29b734f4f10'),
#   'name': '110 Grill',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c59101bec29b734f274e'),
#   'name': '110 Grill',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5b101bec29b734fed04'),
#   'name': '110 Grill',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c57e01bec29b734ea97d'),
#   'name': '110 Grill',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c57e01bec29b734ea97d'),
#   'name': '110 Grill',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c57e01bec29b734ea97d'),
#   'name': '110 Grill',
#   'category': 'Cocktail Bars'},
#  {'_id': ObjectId('6365c5b101bec29b734fed04'),
#   'name': '110 Grill',
#   'category': 'Diners'},
#  {'_id': ObjectId('6365c5b101bec29b734fed13'),
#   'name': '110 Grill',
#   'category': 'Gluten-Free'},
#  {'_id': ObjectId('6365c59801bec29b734f4f10'),
#   'name': '110 Grill',
#   'category': 'Gluten-Free'},
#  {'_id': ObjectId('6365c59101bec29b734f274e'),
#   'name': '110 Grill',
#   'category': 'Gluten-Free'},
#  {'_id': ObjectId('6365c5b101bec29b734fed04'),
#   'name': '110 Grill',
#   'category': 'Gluten-Free'},
#  {'_id': ObjectId('6365c57e01bec29b734ea97d'),
#   'name': '110 Grill',
#   'category': 'Gluten-Free'},
#  {'_id': ObjectId('6365c57e01bec29b734ea97d'),
#   'name': '110 Grill',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5b101bec29b734fed13'),
#   'name': '110 Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59801bec29b734f4f10'),
#   'name': '110 Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59101bec29b734f274e'),
#   'name': '110 Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5b101bec29b734fed04'),
#   'name': '110 Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57e01bec29b734ea97d'),
#   'name': '110 Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a601bec29b734fa3d1'),
#   'name': '111 East',
#   'category': 'Hot Pot'},
#  {'_id': ObjectId('6365c5a601bec29b734fa3d1'),
#   'name': '111 East',
#   'category': 'Pan Asian'},
#  {'_id': ObjectId('6365c5a601bec29b734fa3d1'),
#   'name': '111 East',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Beer Bar'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Ice Cream & Frozen Yogurt'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Tapas/Small Plates'},
#  {'_id': ObjectId('6365c5bc01bec29b73502d25'),
#   'name': '119 French | Bar & Bites',
#   'category': 'Wine Bars'},
#  {'_id': ObjectId('6365c5be01bec29b73503ea9'),
#   'name': '11:11 Health Bar',
#   'category': 'Acai Bowls'},
#  {'_id': ObjectId('6365c5be01bec29b73503ea9'),
#   'name': '11:11 Health Bar',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5be01bec29b73503ea9'),
#   'name': '11:11 Health Bar',
#   'category': 'Juice Bars & Smoothies'},
#  {'_id': ObjectId('6365c5be01bec29b73503ea9'),
#   'name': '11:11 Health Bar',
#   'category': 'Organic Stores'},
#  {'_id': ObjectId('6365c5be01bec29b73503ea9'),
#   'name': '11:11 Health Bar',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5be01bec29b73503ea9'),
#   'name': '11:11 Health Bar',
#   'category': 'Vegan'},
#  {'_id': ObjectId('6365c59401bec29b734f3713'),
#   'name': '11:11 Teahouse',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c59401bec29b734f3713'),
#   'name': '11:11 Teahouse',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59401bec29b734f3713'),
#   'name': '11:11 Teahouse',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5d201bec29b7350be4b'),
#   'name': '11th Street Station',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5d201bec29b7350be4b'),
#   'name': '11th Street Station',
#   'category': 'Soul Food'},
#  {'_id': ObjectId('6365c5d201bec29b7350be4b'),
#   'name': '11th Street Station',
#   'category': 'Southern'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Belgian'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Breweries'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Brewpubs'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Pubs'},
#  {'_id': ObjectId('6365c5b601bec29b7350099d'),
#   'name': '12 Degree Brewing',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57001bec29b734e5309'),
#   'name': '12 West',
#   'category': 'Mexican'},
#  {'_id': ObjectId('6365c57001bec29b734e5309'),
#   'name': '12 West',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a801bec29b734fb310'),
#   'name': '1220 Main Restaurant & Bar',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5a801bec29b734fb310'),
#   'name': '1220 Main Restaurant & Bar',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5a801bec29b734fb310'),
#   'name': '1220 Main Restaurant & Bar',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bf01bec29b7350418a'),
#   'name': '123 Noodles',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c5bf01bec29b7350418a'),
#   'name': '123 Noodles',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bf01bec29b7350418a'),
#   'name': '123 Noodles',
#   'category': 'Vietnamese'},
#  {'_id': ObjectId('6365c57301bec29b734e69a2'),
#   'name': '126 Chinese Restaurant',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c57301bec29b734e69a2'),
#   'name': '126 Chinese Restaurant',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58e01bec29b734f12d1'),
#   'name': '128 Chinese Restaurant',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c58e01bec29b734f12d1'),
#   'name': '128 Chinese Restaurant',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c501bec29b73506902'),
#   'name': '12th Street Bakery',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5c501bec29b73506902'),
#   'name': '12th Street Bakery',
#   'category': 'Bakeries'},
#  {'_id': ObjectId('6365c5c501bec29b73506902'),
#   'name': '12th Street Bakery',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5c501bec29b73506902'),
#   'name': '12th Street Bakery',
#   'category': 'Food Trucks'},
#  {'_id': ObjectId('6365c5c501bec29b73506902'),
#   'name': '12th Street Bakery',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'Breweries'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'Brewpubs'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'Pubs'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57a01bec29b734e8fb6'),
#   'name': '13 Virtues Brewing',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5a401bec29b734f99c6'),
#   'name': '131 Water Kitchen & Bar',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5a401bec29b734f99c6'),
#   'name': '131 Water Kitchen & Bar',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5a401bec29b734f99c6'),
#   'name': '131 Water Kitchen & Bar',
#   'category': 'Pubs'},
#  {'_id': ObjectId('6365c5a401bec29b734f99c6'),
#   'name': '131 Water Kitchen & Bar',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a401bec29b734f99c6'),
#   'name': '131 Water Kitchen & Bar',
#   'category': 'Tapas/Small Plates'},
#  {'_id': ObjectId('6365c5c601bec29b73507017'),
#   'name': '1369 Coffee House',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c58801bec29b734eea83'),
#   'name': '1369 Coffee House',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c5c601bec29b73507017'),
#   'name': '1369 Coffee House',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c58801bec29b734eea83'),
#   'name': '1369 Coffee House',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5c601bec29b73507017'),
#   'name': '1369 Coffee House',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58801bec29b734eea83'),
#   'name': '1369 Coffee House',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5cd01bec29b7350a219'),
#   'name': '14 Twenty Bar and Pizza',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5cd01bec29b7350a219'),
#   'name': '14 Twenty Bar and Pizza',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5cd01bec29b7350a219'),
#   'name': '14 Twenty Bar and Pizza',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5cd01bec29b7350a219'),
#   'name': '14 Twenty Bar and Pizza',
#   'category': 'Pubs'},
#  {'_id': ObjectId('6365c5cd01bec29b7350a219'),
#   'name': '14 Twenty Bar and Pizza',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58801bec29b734ee8f0'),
#   'name': '145F Seafood Boil',
#   'category': 'Cajun/Creole'},
#  {'_id': ObjectId('6365c58801bec29b734ee8f0'),
#   'name': '145F Seafood Boil',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58801bec29b734ee8f0'),
#   'name': '145F Seafood Boil',
#   'category': 'Seafood'},
#  {'_id': ObjectId('6365c5af01bec29b734fe1aa'),
#   'name': '14th Street Bar & Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Beer'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Beer Bar'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Burgers'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Gastropubs'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5be01bec29b73503e22'),
#   'name': '15th Ave Hophouse',
#   'category': 'Wine & Spirits'},
#  {'_id': ObjectId('6365c59101bec29b734f260b'),
#   'name': '15th Street Cafe',
#   'category': 'Cafes'},
#  {'_id': ObjectId('6365c59101bec29b734f260b'),
#   'name': '15th Street Cafe',
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c59101bec29b734f260b'),
#   'name': '15th Street Cafe',
#   'category': 'Hotels'},
#  {'_id': ObjectId('6365c59101bec29b734f260b'),
#   'name': '15th Street Cafe',
#   'category': 'Hotels & Travel'},
#  {'_id': ObjectId('6365c59101bec29b734f260b'),
#   'name': '15th Street Cafe',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Dim Sum'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Noodles'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Singaporean'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Soup'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Thai'},
#  {'_id': ObjectId('6365c59101bec29b734f25ce'),
#   'name': '1618 Asian Fusion',
#   'category': 'Vietnamese'},
#  {'_id': ObjectId('6365c57401bec29b734e6fc4'),
#   'name': '163 Vietnamese Sandwiches & Bubble Tea',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c57401bec29b734e6fc4'),
#   'name': '163 Vietnamese Sandwiches & Bubble Tea',
#   'category': 'Delis'},
#  {'_id': ObjectId('6365c57401bec29b734e6fc4'),
#   'name': '163 Vietnamese Sandwiches & Bubble Tea',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57401bec29b734e6fc4'),
#   'name': '163 Vietnamese Sandwiches & Bubble Tea',
#   'category': 'Juice Bars & Smoothies'},
#  {'_id': ObjectId('6365c57401bec29b734e6fc4'),
#   'name': '163 Vietnamese Sandwiches & Bubble Tea',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57401bec29b734e6fc4'),
#   'name': '163 Vietnamese Sandwiches & Bubble Tea',
#   'category': 'Vietnamese'},
#  {'_id': ObjectId('6365c57f01bec29b734eae7c'),
#   'name': '168 Chinese',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c57f01bec29b734eae7c'),
#   'name': '168 Chinese',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a501bec29b734f9fde'),
#   'name': '168 Chinese Restaurant',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c5a501bec29b734f9fde'),
#   'name': '168 Chinese Restaurant',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c101bec29b73505067'),
#   'name': '16C',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c5c101bec29b73505067'),
#   'name': '16C',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5c101bec29b73505067'),
#   'name': '16C',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c5c101bec29b73505067'),
#   'name': '16C',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c101bec29b73505067'),
#   'name': '16C',
#   'category': 'Salad'},
#  {'_id': ObjectId('6365c57001bec29b734e544e'),
#   'name': '1776 Cheesesteak',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c57001bec29b734e544e'),
#   'name': '1776 Cheesesteak',
#   'category': 'Cheesesteaks'},
#  {'_id': ObjectId('6365c57001bec29b734e544e'),
#   'name': '1776 Cheesesteak',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c57001bec29b734e544e'),
#   'name': '1776 Cheesesteak',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57001bec29b734e544e'),
#   'name': '1776 Cheesesteak',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57001bec29b734e544e'),
#   'name': '1776 Cheesesteak',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c59e01bec29b734f761d'),
#   'name': '18 Monroe Street Market',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c59e01bec29b734f761d'),
#   'name': '18 Monroe Street Market',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c59e01bec29b734f761d'),
#   'name': '18 Monroe Street Market',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c59e01bec29b734f761d'),
#   'name': '18 Monroe Street Market',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a001bec29b734f7ffc'),
#   'name': '180 Cafe',
#   'category': 'Cafes'},
#  {'_id': ObjectId('6365c5a001bec29b734f7ffc'),
#   'name': '180 Cafe',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Bakeries'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Cafes'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Spanish'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Tapas Bars'},
#  {'_id': ObjectId('6365c5ce01bec29b7350a599'),
#   'name': '180 Xurros',
#   'category': 'Vegan'},
#  {'_id': ObjectId('6365c59f01bec29b734f7bb0'),
#   'name': '180 xurros',
#   'category': 'Cafes'},
#  {'_id': ObjectId('6365c59f01bec29b734f7bb0'),
#   'name': '180 xurros',
#   'category': 'Caterers'},
#  {'_id': ObjectId('6365c59f01bec29b734f7bb0'),
#   'name': '180 xurros',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c59f01bec29b734f7bb0'),
#   'name': '180 xurros',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c59f01bec29b734f7bb0'),
#   'name': '180 xurros',
#   'category': 'Donuts'},
#  {'_id': ObjectId('6365c59f01bec29b734f7bb0'),
#   'name': '180 xurros',
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c59f01bec29b734f7bb0'),
#   'name': '180 xurros',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59f01bec29b734f7bb0'),
#   'name': '180 xurros',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59101bec29b734f2874'),
#   'name': '1803 Pizza Kitchen',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c59101bec29b734f2874'),
#   'name': '1803 Pizza Kitchen',
#   'category': 'Bakeries'},
#  {'_id': ObjectId('6365c59101bec29b734f2874'),
#   'name': '1803 Pizza Kitchen',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59101bec29b734f2874'),
#   'name': '1803 Pizza Kitchen',
#   'category': 'Italian'},
#  {'_id': ObjectId('6365c59101bec29b734f2874'),
#   'name': '1803 Pizza Kitchen',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c59101bec29b734f2874'),
#   'name': '1803 Pizza Kitchen',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59101bec29b734f2874'),
#   'name': '1803 Pizza Kitchen',
#   'category': 'Salad'},
#  {'_id': ObjectId('6365c59101bec29b734f2874'),
#   'name': '1803 Pizza Kitchen',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5a401bec29b734f99a4'),
#   'name': '1831Tavern',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5a401bec29b734f99a4'),
#   'name': '1831Tavern',
#   'category': 'Beer'},
#  {'_id': ObjectId('6365c5a401bec29b734f99a4'),
#   'name': '1831Tavern',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5a401bec29b734f99a4'),
#   'name': '1831Tavern',
#   'category': 'Italian'},
#  {'_id': ObjectId('6365c5a401bec29b734f99a4'),
#   'name': '1831Tavern',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5a401bec29b734f99a4'),
#   'name': '1831Tavern',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a401bec29b734f99a4'),
#   'name': '1831Tavern',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5a401bec29b734f99a4'),
#   'name': '1831Tavern',
#   'category': 'Wine & Spirits'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Bakeries'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Caterers'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Delis'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Hotels'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Hotels & Travel'},
#  {'_id': ObjectId('6365c58301bec29b734ec832'),
#   'name': '1886 Cafe & Bakery',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Cocktail Bars'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Dim Sum'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Seafood'},
#  {'_id': ObjectId('6365c5c501bec29b7350688e'),
#   'name': '1886 Chinese Fine Dining',
#   'category': 'Vegetarian'},
#  {'_id': ObjectId('6365c5ca01bec29b73508a51'),
#   'name': '1900 Grill',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5ca01bec29b73508a51'),
#   'name': '1900 Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a701bec29b734fae37'),
#   'name': '1900 Park Fare - Temporarily Unavailable',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5a701bec29b734fae37'),
#   'name': '1900 Park Fare - Temporarily Unavailable',
#   'category': 'Buffets'},
#  {'_id': ObjectId('6365c5a701bec29b734fae37'),
#   'name': '1900 Park Fare - Temporarily Unavailable',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59401bec29b734f38cb'),
#   'name': '1911 Biscuits & Burgers',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c59401bec29b734f38cb'),
#   'name': '1911 Biscuits & Burgers',
#   'category': 'Burgers'},
#  {'_id': ObjectId('6365c59401bec29b734f38cb'),
#   'name': '1911 Biscuits & Burgers',
#   'category': 'Chicken Shop'},
#  {'_id': ObjectId('6365c59401bec29b734f38cb'),
#   'name': '1911 Biscuits & Burgers',
#   'category': 'Comfort Food'},
#  {'_id': ObjectId('6365c59401bec29b734f38cb'),
#   'name': '1911 Biscuits & Burgers',
#   'category': 'Hot Dogs'},
#  {'_id': ObjectId('6365c59401bec29b734f38cb'),
#   'name': '1911 Biscuits & Burgers',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59401bec29b734f38cb'),
#   'name': '1911 Biscuits & Burgers',
#   'category': 'Seafood'},
#  {'_id': ObjectId('6365c59701bec29b734f4acf'),
#   'name': '1914 House',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c59701bec29b734f4acf'),
#   'name': '1914 House',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58d01bec29b734f0c9f'),
#   'name': '192 Burgers & Brews',
#   'category': 'Burgers'},
#  {'_id': ObjectId('6365c58d01bec29b734f0c9f'),
#   'name': '192 Burgers & Brews',
#   'category': 'Fast Food'},
#  {'_id': ObjectId('6365c58d01bec29b734f0c9f'),
#   'name': '192 Burgers & Brews',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5af01bec29b734fe29b'),
#   'name': '1921 Mount Dora',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c5af01bec29b734fe29b'),
#   'name': '1921 Mount Dora',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5af01bec29b734fe29b'),
#   'name': '1921 Mount Dora',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5af01bec29b734fe29b'),
#   'name': '1921 Mount Dora',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5af01bec29b734fe29b'),
#   'name': '1921 Mount Dora',
#   'category': 'Seafood'},
#  {'_id': ObjectId('6365c58201bec29b734ec044'),
#   'name': "1927 S'mores Company",
#   'category': 'Caterers'},
#  {'_id': ObjectId('6365c58201bec29b734ec044'),
#   'name': "1927 S'mores Company",
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c58201bec29b734ec044'),
#   'name': "1927 S'mores Company",
#   'category': 'Do-It-Yourself Food'},
#  {'_id': ObjectId('6365c58201bec29b734ec044'),
#   'name': "1927 S'mores Company",
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c58201bec29b734ec044'),
#   'name': "1927 S'mores Company",
#   'category': 'Food'},
# ...
#  {'_id': ObjectId('6365c5cd01bec29b73509e07'),
#   'name': '303 Café',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5cd01bec29b73509e07'),
#   'name': '303 Café',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5a301bec29b734f941f'),
#   'name': '310 Lakeside',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c5a301bec29b734f941f'),
#   'name': '310 Lakeside',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5a301bec29b734f941f'),
#   'name': '310 Lakeside',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c5a301bec29b734f941f'),
#   'name': '310 Lakeside',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5a301bec29b734f941f'),
#   'name': '310 Lakeside',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a301bec29b734f941f'),
#   'name': '310 Lakeside',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5a301bec29b734f941f'),
#   'name': '310 Lakeside',
#   'category': 'Wine Bars'},
#  {'_id': ObjectId('6365c59901bec29b734f57c2'),
#   'name': '310 Nona',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c59901bec29b734f57c2'),
#   'name': '310 Nona',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c59901bec29b734f57c2'),
#   'name': '310 Nona',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c59901bec29b734f57c2'),
#   'name': '310 Nona',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c59901bec29b734f57c2'),
#   'name': '310 Nona',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59901bec29b734f57c2'),
#   'name': '310 Nona',
#   'category': 'Wine Bars'},
#  {'_id': ObjectId('6365c59a01bec29b734f5b1a'),
#   'name': '310 Park South',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c59a01bec29b734f5b1a'),
#   'name': '310 Park South',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c59a01bec29b734f5b1a'),
#   'name': '310 Park South',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c59a01bec29b734f5b1a'),
#   'name': '310 Park South',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c59a01bec29b734f5b1a'),
#   'name': '310 Park South',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59a01bec29b734f5b1a'),
#   'name': '310 Park South',
#   'category': 'Wine Bars'},
#  {'_id': ObjectId('6365c59b01bec29b734f641f'),
#   'name': '316 Cafe',
#   'category': 'Ethnic Food'},
#  {'_id': ObjectId('6365c59b01bec29b734f641f'),
#   'name': '316 Cafe',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59b01bec29b734f641f'),
#   'name': '316 Cafe',
#   'category': 'Mediterranean'},
#  {'_id': ObjectId('6365c59b01bec29b734f641f'),
#   'name': '316 Cafe',
#   'category': 'Middle Eastern'},
#  {'_id': ObjectId('6365c59b01bec29b734f641f'),
#   'name': '316 Cafe',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59b01bec29b734f641f'),
#   'name': '316 Cafe',
#   'category': 'Specialty Food'},
#  {'_id': ObjectId('6365c57301bec29b734e677a'),
#   'name': '33 & Melt',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c57301bec29b734e677a'),
#   'name': '33 & Melt',
#   'category': 'Comfort Food'},
#  {'_id': ObjectId('6365c57301bec29b734e677a'),
#   'name': '33 & Melt',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57301bec29b734e677a'),
#   'name': '33 & Melt',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57301bec29b734e677a'),
#   'name': '33 & Melt',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c57301bec29b734e677a'),
#   'name': '33 & Melt',
#   'category': 'Specialty Food'},
#  {'_id': ObjectId('6365c57501bec29b734e732f'),
#   'name': '33 Restaurant & Lounge',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c57501bec29b734e732f'),
#   'name': '33 Restaurant & Lounge',
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c57501bec29b734e732f'),
#   'name': '33 Restaurant & Lounge',
#   'category': 'Lounges'},
#  {'_id': ObjectId('6365c57501bec29b734e732f'),
#   'name': '33 Restaurant & Lounge',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c57501bec29b734e732f'),
#   'name': '33 Restaurant & Lounge',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57501bec29b734e732f'),
#   'name': '33 Restaurant & Lounge',
#   'category': 'Venues & Event Spaces'},
#  {'_id': ObjectId('6365c5bc01bec29b73502fd5'),
#   'name': '3350 Poke Cafe',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c5bc01bec29b73502fd5'),
#   'name': '3350 Poke Cafe',
#   'category': 'Burgers'},
#  {'_id': ObjectId('6365c5bc01bec29b73502fd5'),
#   'name': '3350 Poke Cafe',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bc01bec29b73502fd5'),
#   'name': '3350 Poke Cafe',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c57501bec29b734e729c'),
#   'name': '338 Grill',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c57501bec29b734e729c'),
#   'name': '338 Grill',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c57501bec29b734e729c'),
#   'name': '338 Grill',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c57501bec29b734e729c'),
#   'name': '338 Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57401bec29b734e6ad1'),
#   'name': '34th Street Cafe',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c57401bec29b734e6ad1'),
#   'name': '34th Street Cafe',
#   'category': 'Caterers'},
#  {'_id': ObjectId('6365c57401bec29b734e6ad1'),
#   'name': '34th Street Cafe',
#   'category': 'Event Planning & Services'},
#  {'_id': ObjectId('6365c57401bec29b734e6ad1'),
#   'name': '34th Street Cafe',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Beer'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Cafes'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Cocktail Bars'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'French'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Latin American'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Sports Bars'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Wine & Spirits'},
#  {'_id': ObjectId('6365c5af01bec29b734fdea2'),
#   'name': '360 American Bistro & Bar',
#   'category': 'Wine Bars'},
#  {'_id': ObjectId('6365c5a101bec29b734f87b7'),
#   'name': '360 Cafe',
#   'category': 'Cajun/Creole'},
#  {'_id': ObjectId('6365c5a101bec29b734f87b7'),
#   'name': '360 Cafe',
#   'category': 'Karaoke'},
#  {'_id': ObjectId('6365c5a101bec29b734f87b7'),
#   'name': '360 Cafe',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5a101bec29b734f87b7'),
#   'name': '360 Cafe',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5a101bec29b734f87b7'),
#   'name': '360 Cafe',
#   'category': 'Vietnamese'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Beer'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c5ac01bec29b734fccd2'),
#   'name': '360 Pizza',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f14'),
#   'name': '360 Pizza',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c5ac01bec29b734fccd2'),
#   'name': '360 Pizza',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f14'),
#   'name': '360 Pizza',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f14'),
#   'name': '360 Pizza',
#   'category': 'Food Delivery Services'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Food Delivery Services'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f14'),
#   'name': '360 Pizza',
#   'category': 'Gluten-Free'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Italian'},
#  {'_id': ObjectId('6365c5ac01bec29b734fccd2'),
#   'name': '360 Pizza',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f14'),
#   'name': '360 Pizza',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c5ac01bec29b734fccd2'),
#   'name': '360 Pizza',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f14'),
#   'name': '360 Pizza',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f14'),
#   'name': '360 Pizza',
#   'category': 'Salad'},
#  {'_id': ObjectId('6365c5ac01bec29b734fccd2'),
#   'name': '360 Pizza',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c57a01bec29b734e8f14'),
#   'name': '360 Pizza',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c57901bec29b734e8b8c'),
#   'name': '360 Pizza',
#   'category': 'Wine & Spirits'},
#  {'_id': ObjectId('6365c58101bec29b734eb9c2'),
#   'name': '360 Primo Coffee Shop',
#   'category': 'Bagels'},
#  {'_id': ObjectId('6365c58101bec29b734eb9c2'),
#   'name': '360 Primo Coffee Shop',
#   'category': 'Bakeries'},
#  {'_id': ObjectId('6365c58101bec29b734eb9c2'),
#   'name': '360 Primo Coffee Shop',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c58101bec29b734eb9c2'),
#   'name': '360 Primo Coffee Shop',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c58101bec29b734eb9c2'),
#   'name': '360 Primo Coffee Shop',
#   'category': 'Ice Cream & Frozen Yogurt'},
#  {'_id': ObjectId('6365c58101bec29b734eb9c2'),
#   'name': '360 Primo Coffee Shop',
#   'category': 'Italian'},
#  {'_id': ObjectId('6365c58101bec29b734eb9c2'),
#   'name': '360 Primo Coffee Shop',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58101bec29b734eb9c2'),
#   'name': '360 Primo Coffee Shop',
#   'category': 'Sandwiches'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Arts & Entertainment'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Bars'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Breakfast & Brunch'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Coffee & Tea'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Delis'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Desserts'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Italian'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Nightlife'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Wine Bars'},
#  {'_id': ObjectId('6365c5d101bec29b7350b995'),
#   'name': '360 UNO',
#   'category': 'Wineries'},
#  {'_id': ObjectId('6365c58801bec29b734ee9e0'),
#   'name': '38 Sampal Korean BBQ',
#   'category': 'Barbeque'},
#  {'_id': ObjectId('6365c58801bec29b734ee9e0'),
#   'name': '38 Sampal Korean BBQ',
#   'category': 'Korean'},
#  {'_id': ObjectId('6365c58801bec29b734ee9e0'),
#   'name': '38 Sampal Korean BBQ',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5cd01bec29b7350a0b7'),
#   'name': '3A Pizza and Grill',
#   'category': 'Italian'},
#  {'_id': ObjectId('6365c5cd01bec29b7350a0b7'),
#   'name': '3A Pizza and Grill',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c5cd01bec29b7350a0b7'),
#   'name': '3A Pizza and Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5ba01bec29b73501e45'),
#   'name': '3G Vegetarian Restaurant',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5ba01bec29b73501e45'),
#   'name': '3G Vegetarian Restaurant',
#   'category': 'Vegetarian'},
#  {'_id': ObjectId('6365c59501bec29b734f408f'),
#   'name': '3Natives',
#   'category': 'Acai Bowls'},
#  {'_id': ObjectId('6365c59501bec29b734f408f'),
#   'name': '3Natives',
#   'category': 'Cafes'},
#  {'_id': ObjectId('6365c59501bec29b734f408f'),
#   'name': '3Natives',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c59501bec29b734f408f'),
#   'name': '3Natives',
#   'category': 'Gelato'},
#  {'_id': ObjectId('6365c59501bec29b734f408f'),
#   'name': '3Natives',
#   'category': 'Juice Bars & Smoothies'},
#  {'_id': ObjectId('6365c59501bec29b734f408f'),
#   'name': '3Natives',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59501bec29b734f408f'),
#   'name': '3Natives',
#   'category': 'Wraps'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Active Life'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Chocolatiers & Shops'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Fitness & Instruction'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Food'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Health & Medical'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Herbal Shops'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Juice Bars & Smoothies'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Live/Raw Food'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Mediators'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Meditation Centers'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Professional Services'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Specialty Food'},
#  {'_id': ObjectId('6365c5be01bec29b735038b1'),
#   'name': '3rd Eye Lounge & Elixir Bar',
#   'category': 'Yoga'},
#  {'_id': ObjectId('6365c59601bec29b734f4560'),
#   'name': '4 Brothers Pizza',
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c59601bec29b734f4560'),
#   'name': '4 Brothers Pizza',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58801bec29b734ee902'),
#   'name': "4 Brothers' Pizza",
#   'category': 'Pizza'},
#  {'_id': ObjectId('6365c58801bec29b734ee902'),
#   'name': "4 Brothers' Pizza",
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5d001bec29b7350b074'),
#   'name': '4 Caminos',
#   'category': 'Food Stands'},
#  {'_id': ObjectId('6365c5d001bec29b7350b074'),
#   'name': '4 Caminos',
#   'category': 'Mexican'},
#  {'_id': ObjectId('6365c5d001bec29b7350b074'),
#   'name': '4 Caminos',
#   'category': 'Restaurants'},
#  ...]

# %%
q4c_pipeline = [
    {'$match': {'$text': {'$search': 'Restaurants'}}},
    {'$set' : { 'cat' : {'$split': ['$categories',', ']}}},
    {'$unwind' : '$cat'},
    {'$project' : {'_id':'$_id','name':'$name','category': '$cat'}},
    {'$sort' : {'name' : 1, 'category' : 1}}  
]

result_4c = list(business.aggregate(q4c_pipeline))

# %%
# Do not delete/edit this cell
result_4c = list(business.aggregate(q4c_pipeline))[10000:10050]
pickle.dump(result_4c, open("results/result_4c.p", "wb"))

# %%
grader.check("q4c")
# Out:
# q4c results: All test cases passed!

# %%
pickle.load(open("results/result_4c.p", "rb"))
# Out:
# [{'_id': ObjectId('6365c58501bec29b734ed56e'),
#   'name': 'Asian Fusion Bowl',
#   'category': 'Street Vendors'},
#  {'_id': ObjectId('6365c5cc01bec29b735098fe'),
#   'name': 'Asian Fusion Cafe',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c5cc01bec29b735098fe'),
#   'name': 'Asian Fusion Cafe',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5ae01bec29b734fd8cd'),
#   'name': 'Asian Garden',
#   'category': 'American (Traditional)'},
#  {'_id': ObjectId('6365c5ae01bec29b734fd8cd'),
#   'name': 'Asian Garden',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c59001bec29b734f1f3a'),
#   'name': 'Asian Garden',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c58101bec29b734ebedc'),
#   'name': 'Asian Garden',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c58101bec29b734ebedc'),
#   'name': 'Asian Garden',
#   'category': 'Korean'},
#  {'_id': ObjectId('6365c59001bec29b734f1f3a'),
#   'name': 'Asian Garden',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5ae01bec29b734fd8cd'),
#   'name': 'Asian Garden',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58101bec29b734ebedc'),
#   'name': 'Asian Garden',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59001bec29b734f1f3a'),
#   'name': 'Asian Garden',
#   'category': 'Seafood'},
#  {'_id': ObjectId('6365c58101bec29b734ebedc'),
#   'name': 'Asian Garden',
#   'category': 'Soup'},
#  {'_id': ObjectId('6365c58101bec29b734ebedc'),
#   'name': 'Asian Garden',
#   'category': 'Thai'},
#  {'_id': ObjectId('6365c57501bec29b734e7358'),
#   'name': 'Asian Garden Buffet',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c57501bec29b734e7358'),
#   'name': 'Asian Garden Buffet',
#   'category': 'Buffets'},
#  {'_id': ObjectId('6365c57501bec29b734e7358'),
#   'name': 'Asian Garden Buffet',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c57501bec29b734e7358'),
#   'name': 'Asian Garden Buffet',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57c01bec29b734e9df9'),
#   'name': 'Asian Go',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c57c01bec29b734e9df9'),
#   'name': 'Asian Go',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c57c01bec29b734e9df9'),
#   'name': 'Asian Go',
#   'category': 'Sushi Bars'},
#  {'_id': ObjectId('6365c5bf01bec29b7350432b'),
#   'name': 'Asian Gourmet',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c5bf01bec29b7350432b'),
#   'name': 'Asian Gourmet',
#   'category': 'Japanese'},
#  {'_id': ObjectId('6365c5bf01bec29b7350432b'),
#   'name': 'Asian Gourmet',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5bf01bec29b7350432b'),
#   'name': 'Asian Gourmet',
#   'category': 'Sushi Bars'},
#  {'_id': ObjectId('6365c59801bec29b734f52df'),
#   'name': 'Asian Gourmet & Sushi Bar',
#   'category': 'American (New)'},
#  {'_id': ObjectId('6365c59801bec29b734f52df'),
#   'name': 'Asian Gourmet & Sushi Bar',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c59801bec29b734f52df'),
#   'name': 'Asian Gourmet & Sushi Bar',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c59801bec29b734f52df'),
#   'name': 'Asian Gourmet & Sushi Bar',
#   'category': 'Japanese'},
#  {'_id': ObjectId('6365c59801bec29b734f52df'),
#   'name': 'Asian Gourmet & Sushi Bar',
#   'category': 'Pan Asian'},
#  {'_id': ObjectId('6365c59801bec29b734f52df'),
#   'name': 'Asian Gourmet & Sushi Bar',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59801bec29b734f52df'),
#   'name': 'Asian Gourmet & Sushi Bar',
#   'category': 'Sushi Bars'},
#  {'_id': ObjectId('6365c58301bec29b734ec601'),
#   'name': 'Asian Grill',
#   'category': 'Japanese'},
#  {'_id': ObjectId('6365c58301bec29b734ec601'),
#   'name': 'Asian Grill',
#   'category': 'Korean'},
#  {'_id': ObjectId('6365c58301bec29b734ec601'),
#   'name': 'Asian Grill',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c58301bec29b734ec601'),
#   'name': 'Asian Grill',
#   'category': 'Sushi Bars'},
#  {'_id': ObjectId('6365c59c01bec29b734f67d6'),
#   'name': 'Asian Harbor',
#   'category': 'Buffets'},
#  {'_id': ObjectId('6365c59c01bec29b734f67d6'),
#   'name': 'Asian Harbor',
#   'category': 'Cantonese'},
#  {'_id': ObjectId('6365c59c01bec29b734f67d6'),
#   'name': 'Asian Harbor',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c59c01bec29b734f67d6'),
#   'name': 'Asian Harbor',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59c01bec29b734f67d6'),
#   'name': 'Asian Harbor',
#   'category': 'Sushi Bars'},
#  {'_id': ObjectId('6365c59c01bec29b734f67d6'),
#   'name': 'Asian Harbor',
#   'category': 'Szechuan'},
#  {'_id': ObjectId('6365c58e01bec29b734f1092'),
#   'name': 'Asian Hibachi Express',
#   'category': 'Japanese'},
#  {'_id': ObjectId('6365c58e01bec29b734f1092'),
#   'name': 'Asian Hibachi Express',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c59c01bec29b734f6990'),
#   'name': 'Asian Hibachi and Sushi Buffet',
#   'category': 'Asian Fusion'},
#  {'_id': ObjectId('6365c59c01bec29b734f6990'),
#   'name': 'Asian Hibachi and Sushi Buffet',
#   'category': 'Buffets'},
#  {'_id': ObjectId('6365c59c01bec29b734f6990'),
#   'name': 'Asian Hibachi and Sushi Buffet',
#   'category': 'Chinese'},
#  {'_id': ObjectId('6365c59c01bec29b734f6990'),
#   'name': 'Asian Hibachi and Sushi Buffet',
#   'category': 'Japanese'},
#  {'_id': ObjectId('6365c59c01bec29b734f6990'),
#   'name': 'Asian Hibachi and Sushi Buffet',
#   'category': 'Restaurants'},
#  {'_id': ObjectId('6365c5d101bec29b7350bbe4'),
#   'name': 'Asian House',
#   'category': 'Asian Fusion'}]

# %% [markdown]
# ### Question 4d
# This change in representation has made it super easy to view all the vegetarian restaurants and count them without the use of an index since we can now simply filter by whether or not 'Vegetarian' is a field in our document! We have provided some code here to count how many vegetarian restaurants are in our dataset. Simply provide the integer count to get a point for this question :)

# %%
q4d_pipeline = q4c_pipeline[:]
q4d_pipeline.append({"$match": {"category": 'Vegetarian'}})
result_4d = list(business.aggregate(q4d_pipeline))

veg_count = len(result_4d)
veg_count
# Out:
# 1482

# %%
# Do not delete/edit this cell
pickle.dump(veg_count, open("results/result_4d.p", "wb"))

# %%
grader.check("q4d")
# Out:
# q4d results: All test cases passed!

# %% [markdown]
# ## Congratulations! You have finished Project 4.
#
# Run the following cell to zip and download the results of your queries. You will also need to run the export cell at the end of the notebook.
#
# **For submission on Gradescope, you will need to submit BOTH the proj4.zip file genreated by the export cell and the results.zip file generated by the following cell.**
#
# **Common submission issues:** You MUST submit the generated zip files (not folders) to the autograder. However, Safari is known to automatically unzip files upon downloading. You can fix this by going into Safari preferences, and deselect the box with the text "Open safe files after downloading" under the "General" tab. If you experience issues with downloading via clicking on the link, you can also navigate to the project 4 directory within JupyterHub (remove `proj4.ipynb` from the url), and manually download the generated zip files. Please post on Ed if you encounter any other submission issues.

# %%
from IPython.display import display, FileLink

# !zip -r results.zip results
results_file = FileLink('./results.zip', result_html_prefix="Click here to download: ")
display(results_file)
# Out:
# updating: results/ (stored 0%)
# updating: results/result_1a.p (deflated 13%)
# updating: results/result_1b.p (deflated 10%)
# updating: results/result_1c.p (deflated 71%)
# updating: results/result_1d.p (deflated 20%)
# updating: results/result_1e.p (deflated 59%)
# updating: results/result_1f.p (deflated 18%)
# updating: results/result_2b.csv (deflated 46%)
# updating: results/result_2c.p (deflated 58%)
# updating: results/result_3b.csv (deflated 69%)
# updating: results/result_3c.csv (deflated 59%)
# updating: results/result_3e.csv (deflated 74%)
# updating: results/result_4a.p (deflated 20%)
# updating: results/result_4b.p (deflated 20%)
# updating: results/result_4c.p (deflated 85%)
# updating: results/result_4d.p (deflated 20%)
# /home/jovyan/fa22/proj/proj4/results.zip

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q1a results: All test cases passed!
#
# q1b results: All test cases passed!
#
# q1c results: All test cases passed!
#
# q1d results: All test cases passed!
#
# q1e results: All test cases passed!
#
# q1f results: All test cases passed!
#
# q2b results: All test cases passed!
#
# q2c results: All test cases passed!
#
# q3b results: All test cases passed!
#
# q3c results: All test cases passed!
#
# q3d results: All test cases passed!
#
# q3e results: All test cases passed!
#
# q3fi results: All test cases passed!
#
# q3fii results: All test cases passed!
#
# q3fiii results: All test cases passed!
#
# q4a results: All test cases passed!
#
# q4b results: All test cases passed!
#
# q4c results: All test cases passed!
#
# q4d results: All test cases passed!

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export()
# Out:
#             <p>Your submission has been exported. Click <a href="proj4_2022_12_02T23_46_54_138540.zip" download="proj4_2022_12_02T23_46_54_138540.zip" target="_blank">here</a>
#             to download the zip file.</p>
